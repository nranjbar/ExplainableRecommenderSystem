# %% [markdown]
# Link to Drive files for cell-phone dataset: https://drive.google.com/file/d/1ET7rXNa5vAhWNLK6YQsbuQsiQNavO2sL/view?usp=share_link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Preprocessing...

# %%
import pandas as pd
import numpy as np
import torch
import json
import matplotlib.pyplot as plt
import os
import tqdm
import pickle
from pathlib import Path
from torch.utils.data import DataLoader
from sklearn.metrics import ndcg_score
np.random.seed(0)

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Cell_Phones_and_Accessories.json.gz
# Out:
# --2022-05-30 13:42:20--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFiles/Cell_Phones_and_Accessories.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1232323281 (1.1G) [application/octet-stream]
# Saving to: ‘Cell_Phones_and_Accessories.json.gz’
#
# Cell_Phones_and_Acc 100%[===================>]   1.15G  18.3MB/s    in 66s
#
# 2022-05-30 13:43:26 (17.8 MB/s) - ‘Cell_Phones_and_Accessories.json.gz’ saved [1232323281/1232323281]

# %%
# !gunzip Cell_Phones_and_Accessories.json.gz

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_Cell_Phones_and_Accessories.json.gz
# Out:
# --2022-05-30 13:43:27--  http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_Cell_Phones_and_Accessories.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 360006372 (343M) [application/octet-stream]
# Saving to: ‘meta_Cell_Phones_and_Accessories.json.gz’
#
# meta_Cell_Phones_an 100%[===================>] 343.33M  18.2MB/s    in 20s
#
# 2022-05-30 13:43:47 (17.1 MB/s) - ‘meta_Cell_Phones_and_Accessories.json.gz’ saved [360006372/360006372]

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk import FreqDist
import re
from nltk.tokenize import RegexpTokenizer
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize,pos_tag

# %%
save_path='/content/drive/MyDrive/cell_phone/'

# %%
df_review=pd.read_csv(save_path+'df_reviews.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_meta=pd.read_csv(save_path+'df_meta.csv')

# %%
df_review.drop(df_review.index[~df_review['asin'].isin(df_meta['asin'])], inplace=True)

# %%
import glob
items_list=[]
names=glob.glob(save_path+"description_bert/*.json")
for name in names:
  # items_dframe=pd.read_json(name)
  item_id=name.split('/')[-1].split('_')[-1][0:-5]
  items_list.append(item_id)

# %%
df_review.drop(df_review.index[~df_review['asin'].isin(items_list)], inplace=True)

# %%
df_review.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df_review.drop_duplicates(inplace=True)

# %%
items_list1=[]
users_list=[]
review_features={}
f=open(save_path+'Cell_Phones_and_Accessories')
lines=f.readlines()
i=0
for line in lines:
  if i%5000==0:
    print(i)
  i+=1
  user_id = line.split('@')[0]
  item_id = line.split('@')[1]
  if item_id in items_list:
    users_list.append(user_id)
    items_list1.append(item_id)
    l = len(user_id) + len(item_id)
    fosr_data = line[l+3:]
    for seg in fosr_data.split('||'):
      if (user_id,item_id) not in review_features.keys():
        review_features[(user_id,item_id)]=[]
      fos = seg.split(':')[0].strip('|')
      if len(fos.split('|')) > 1:
          feature = fos.split('|')[0]
          opinion = fos.split('|')[1]
          sentiment = fos.split('|')[2]
          sentence= seg.split(':')[1]
          if sentiment=='+1':
            senti=1
          else:
            senti=-1
          review_features[(user_id,item_id)].append([feature,opinion,senti,sentence])
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000

# %%
df_review=df_review[df_review.set_index(['reviewerID','asin']).index.isin(review_features.keys())]

# %%
sentires_dir='/content/Cell_Phones_and_Accessories'
test_length=5
sample_ratio=2
# val_length=1
neg_length=50
dataset='cell_phones'
save_path='/content/drive/MyDrive/Recommender/cell_phone/'

# %%
def get_user_item_dict(df_review,items_list):
  user_dict = {}
  item_dict = {}
  removed_users=['A1ULCCHD1QNOS5','A1ZS098EKPVT8F','A1K1WK6I122RX2','A2PAFKGAUSBMIE','AAOYA0DKWED4W','AJS9Q2JYS3DLJ','ADOF1VKGDCBWF','A3G11XDKGXZT9Q','A1R233YLWSRBTC','A3VH9QMH2UTX9D','A15DZOS6KVANQH']    
  for index, row in df_review.iterrows():
    user=row['reviewerID']
    item=row['asin']
    if user not in removed_users and item in items_list:
      if user not in user_dict:
          user_dict[user] = [item]
      else:
          user_dict[user].append(item)
      if item not in item_dict:
          item_dict[item] = [user]
      else:
          item_dict[item].append(user)
  return user_dict,item_dict

# %%
df_meta.loc[df_meta['feature'].str.len()<15]
# Out:
#         Unnamed: 0                                        description  \
# 342           4082                    ['Blueant product, not a fake']
# 376           4470  ['Do it Swivel Glide - For installation in hol...
# 483           5453  ['Lucky Line Leather Belt Hook Key Ring - Made...
# 889           9733  ['Mot W385 Standard 940 mAh lithium ion Battery']
# 958          10463     ['LG VX8550 Chocolate Standard Battery Black']
# ...            ...                                                ...
# 104134      585106  ['perfectly fit, easy to install, covering the...
# 104157      585147  ['perfectly fit, easy to install, covering the...
# 104173      585200  ['perfectly fit, easy to install, covering the...
# 104929      588361  ['perfectly fit, easy to install, covering the...
# 105089      589106                                   ['7 Plus Black']
#
#                                                     title        feature  \
# 342     SUPERTOOTH LIGHT BLUETOOTH MOBILE PHONE HANDSF...  ['brand new']
# 376                                          Swivel Glide      ['China']
# 483                    Lucky Line 45301 Leather Belt Hook      ['China']
# 889          Motorola K1m W220 W385 Z6m Z6tv BT51 Battery  ['Batteries']
# 958                 LG VX8550 Chocolate Std Battery Black  ['Batteries']
# ...                                                   ...            ...
# 104134  Galaxy S7 Active Case, DuroCase Hybrid Dual La...  ['Discovery']
# 104157  LG Stylo 2 Plus Case / LG Stylus 2 Plus Case, ...  ['Discovery']
# 104173  LG Stylo 2 Plus Case / LG Stylus 2 Plus Case, ...  ['Discovery']
# 104929  DKmagic 6PCS Mini Earphone SD Card Macarons Ba...  ['Discovery']
# 105089  Krusell Orsa FolioCase iPhone 8/7 Plus Black, ...      ['60766']
#
#                                                      rank    price        asin
# 342     ['>#3,652,634 in Cell Phones & Accessories (Se...  $149.99  B000FQ4GT0
# 376     ['>#1,892,113 in Tools & Home Improvement (See...    $6.99  B000HE4TPG
# 483     ['>#1,885,591 in Cell Phones & Accessories (Se...    $6.71  B000LNU0NI
# 889     ['>#101,575 in Cell Phones & Accessories (See ...    $4.47  B001680REO
# 958     ['>#415,269 in Cell Phones & Accessories (See ...    $5.48  B0019F6WXE
# ...                                                   ...      ...         ...
# 104134  ['>#1,526,176 in Cell Phones & Accessories (Se...   $11.29  B01H0YUGU2
# 104157  ['>#347,482 in Cell Phones & Accessories (See ...   $11.29  B01H12AL12
# 104173  ['>#2,052,064 in Cell Phones & Accessories (Se...   $11.29  B01H149Z80
# 104929  ['>#1,220,879 in Cell Phones & Accessories (Se...    $2.96  B01HCSDRHA
# 105089  ['>#4,551,229 in Cell Phones & Accessories (Se...   $39.90  B01HFFRWY4
#
# [259 rows x 7 columns]

# %%
def get_normalized_rank(df_meta):
  ranks_dict={}
  for ind, row  in df_meta.iterrows():
    rank=row['rank']
    item_id=row['asin']
    numbers= rank.split('#')
    mean_rank=0
    count=0
    for num_text in numbers:
      if num_text.find(' ')>-1:
        num=float(num_text[0:num_text.find(' ')].replace(',',''))
        mean_rank+=num
        count+=1
    mean_rank/=(count)
    ranks_dict[item_id]=mean_rank
  minv=min(ranks_dict.values())
  maxv=max(ranks_dict.values())
  for k in ranks_dict:
    # print(ranks_dict[k])
    # print(minv)
    # print(maxv)
    ranks_dict[k] = (ranks_dict[k]-minv)/(maxv-minv)
  return ranks_dict

# %%
import os

# %%
def get_average_vect_train(df,not_in_columns):
  df['main_word']=np.where(df['replaced_word'] == df[not_in_columns],1,0)
  df=df[df['main_word']==1]
  lists=df.loc[:, ~df.columns.isin([not_in_columns,'replaced_word','logit','main_word'])].values
  words=df[not_in_columns].values
  # print(words)
  vects=[sub_list[0] for sub_list in lists]
  average=np.average(np.array(vects),axis=0)
  # print(words)
  # print(df)
  return average,list(words)

# %%
def get_average_vect_test(weights,tensor_vect):
  # weights=torch.FloatTensor(weights).to(device)
  weights=torch.transpose(weights.repeat(tensor_vect.shape[1],1),0,1)
  average=torch.mean(weights*tensor_vect,axis=0).to(device)
  return average

# %%
import os

# %%
from typing_extensions import final
def get_item_matrix(item_name_dict,items_list):
  print('----- get items matrix -------')
  item_quality_matrix = np.zeros((len(item_name_dict), 2304))
  print((len(item_name_dict)))
  i=0
  features={}
  for item_id in items_list:
    if item_id in item_name_dict.keys():
      item=item_name_dict[item_id]
      features[item]=[]
      if i%100==0:
        print(i)
      i+=1
      final_vector=[]
      # print(item_id)
      df_vect_desc_item= pd.read_json(save_path+'description_bert/'+'df_bert_desc_{}.json'.format(item_id))
      df_vect_title_item= pd.read_json(save_path+'title_bert/'+'df_bert_title_{}.json'.format(item_id))
      df_vect_feature_item= pd.read_json(save_path+'feature_bert/'+'df_bert_feature_{}.json'.format(item_id))

      # print(item_id)
      # print(df_vect_desc_item)

      average_vect_desc,words_desc=get_average_vect_train(df_vect_desc_item,'description_words')
      average_vect_title,words_title=get_average_vect_train(df_vect_title_item,'title_words')
      average_vect_feature,words_feature=get_average_vect_train(df_vect_feature_item,'feature_words')

      features[item].append(words_desc)
      features[item].append(words_title)
      features[item].append(words_feature)
      # features[item].append(words_senti)
      # features[item].append([rank])
      final_vector=list(average_vect_desc)
      final_vector+=list(average_vect_title)
      final_vector+=list(average_vect_feature)
  # final_vector+=list(average_bert_sentiment)
  # final_vector+=[rank]
  
      if len(final_vector)>2304:
          print(len(list(average_vect_desc)))
          print(len(list(average_vect_title)))
          print(len(list(average_vect_feature)))
          # print(len(list(average_bert_sentiment)))
          print(item_id)
      item_quality_matrix[item]=final_vector
      # print(item_quality_matrix)

  item_quality_matrix = np.array(item_quality_matrix, dtype='float32')
  return item_quality_matrix,features

# %%
def get_user_matrix(item_matrix,inv_user_name_dict,item_name_dict):
  user_quality_matrix = np.zeros((len(inv_user_name_dict), 2304))
  i=0
  print('----- get users matrix -------')
  print((len(inv_user_name_dict)))
  for  user in inv_user_name_dict.keys():
    if i%1000==0:
      print(i)
    i+=1
    user_id= inv_user_name_dict[user]
    final_vector=[]
    items_interacted=df_review[df_review['reviewerID']==user_id ]
    # mean_rate=np.average(items_interacted['overall'].values)
    # weights=[]
    for item_id in items_interacted['asin'].values:
      if item_id in item_name_dict.keys():
        item=item_name_dict[item_id]
        # weight=items_interacted[items_interacted['asin']==item_id]['overall'].values[0]-mean_rate
        # weights.append(weight)
        final_vector.append(item_matrix[item])
    # if np.sum(weights)>0 or np.sum(weights)<0:
    #   final_average=np.average(final_vector,weights=weights,axis=0)
    # else:
    final_average=np.average(final_vector,axis=0)
    if ~np.isnan(np.sum(final_average)):
      user_quality_matrix[user]=final_average
    else:
      print(user_id)
  user_quality_matrix = np.array(user_quality_matrix, dtype='float32')
  return user_quality_matrix

# %%
def sample_training_pairs(user, training_items, item_set, sample_ratio=5):
    positive_items = set(training_items)
    negative_items = set()
    for item in item_set:
        if item not in positive_items:
            negative_items.add(item)
    neg_length = len(positive_items) * sample_ratio
    negative_items = np.random.choice(np.array(list(negative_items)), neg_length, replace=False)
    train_pairs = []
    for p_item in positive_items:
        train_pairs.append([user, p_item, 1])
    for n_item in negative_items:
        train_pairs.append([user, n_item, 0])
    return train_pairs

# %%
import glob
def get_items_list():
  items_list=[]
  names=glob.glob(save_path+"titles_bert/*.json")
  for name in names:
    items_list.append(name.split('/')[-1].split('_')[-1][0:-5])
  return items_list

# %%
final_items = []
final_users=[]
training_pairs = np.loadtxt(save_path+'training_data.txt',dtype=str)
for pair in training_pairs:
  final_items.append(pair[1])
  final_users.append(pair[0])
with open(save_path+'test_data.pickle', 'rb') as f:
  test_pairs= pickle.load(f)
  for user_id in test_pairs.keys():
    final_users.append(user_id)
    items_ids=test_pairs[user_id][0]
    final_items+=items_ids
final_items=list(set(final_items))
final_users=list(set(final_users))

# %%
print(len(final_items))
print(len(final_users))
# Out:
# 1907
# 93

# %%
from re import S
import torch
import numpy as np
import json
import pickle
# from torch._C import R
import tqdm
from torch.random import seed


class AmazonDataset():
    def __init__(self):
        super().__init__()

        self.user_name_dict = {}  # rename users to integer names
        self.item_name_dict = {}
        self.feature_name_dict = {}

        self.features = {}  # feature list
        self.users = []
        self.items = []

        # the interacted items for each user, sorted with date {user:[i1, i2, i3, ...], user:[i1, i2, i3, ...]}
        self.user_hist_inter_dict = {}
        # the interacted users for each item
        self.item_hist_inter_dict = {}  

        self.user_num = None
        self.item_num = None
        self.feature_num = 2304# number of features

        self.user_feature_matrix = None  # user aspect attention matrix
        self.item_feature_matrix = None  # item aspect quality matrix

        self.training_data = None
        self.test_data = None
        self.pre_processing()
        self.get_user_item_feature_matrix()
        self.sample_training()  # sample training data, for traning BPR loss
        self.sample_test()  # sample test data

    def pre_processing(self,):
        self.items_list=get_items_list()
        user_dict, item_dict = get_user_item_dict(df_review,self.items_list)  # not sorted with time
        print(len(item_dict))
        user_item_date_dict = {}   # {(user, item): date, (user, item): date ...}  # used to remove duplicate
        removed_users=['A1ULCCHD1QNOS5','A1ZS098EKPVT8F','A1K1WK6I122RX2','A2PAFKGAUSBMIE','AAOYA0DKWED4W','AJS9Q2JYS3DLJ','ADOF1VKGDCBWF','A3G11XDKGXZT9Q','A1R233YLWSRBTC','A3VH9QMH2UTX9D','A15DZOS6KVANQH']
        for i, row in df_review.iterrows():
            user = row['reviewerID']
            if user not in removed_users:
              item = row['asin']
              date = row['unixReviewTime']
              if item in self.items_list:
                if user in user_dict and item in user_dict[user] and (user, item) not in user_item_date_dict:
                    user_item_date_dict[(user, item)] = date
        
        # rename users, items, and features to integer names
        user_name_dict = {}
        item_name_dict = {}
        # feature_name_dict = {}
        # features = get_feature_list(df_bert_sentiment,df_bert_desc,)
        
        count = 0
        for user in user_dict:
            if user not in user_name_dict:
                user_name_dict[user] = count
                count += 1
        count = 0
        for item in item_dict:
            if item not in item_name_dict:
                item_name_dict[item] = count
                count += 1
        self.inv_user_name_dict = {v: k for k, v in user_name_dict.items()}
        self.inv_item_name_dict = {v: k for k, v in item_name_dict.items()}
        
        # for i in range(len(sentiment_data)):
        #     sentiment_data[i][0] = user_name_dict[sentiment_data[i][0]]
        #     sentiment_data[i][1] = item_name_dict[sentiment_data[i][1]]
        #     for j in range(len(sentiment_data[i]) - 2):
        #         sentiment_data[i][j+2][0] = feature_name_dict[sentiment_data[i][j + 2][0]]

        renamed_user_item_date_dict = {}
        for key, value in user_item_date_dict.items():
            renamed_user_item_date_dict[user_name_dict[key[0]], item_name_dict[key[1]]] = value

        # sort with date
        renamed_user_item_date_dict  = dict(sorted(renamed_user_item_date_dict .items(), key=lambda item: item[1]))

        user_hist_inter_dict = {}  # {"u1": [i1, i2, i3, ...], "u2": [i1, i2, i3, ...]}, sort with time
        item_hist_inter_dict = {}
        # ranked_user_item_dict = {}  # {"u1": [i1, i2, i3, ...], "u2": [i1, i2, i3, ...]}
        for key, value in renamed_user_item_date_dict.items():
            user = key[0]
            item = key[1]
            if user not in user_hist_inter_dict:
                user_hist_inter_dict[user] = [item]
            else:
                user_hist_inter_dict[user].append(item)
            if item not in item_hist_inter_dict:
                item_hist_inter_dict[item] = [user]
            else:
                item_hist_inter_dict[item].append(user)

        user_hist_inter_dict = dict(sorted(user_hist_inter_dict.items()))
        item_hist_inter_dict = dict(sorted(item_hist_inter_dict.items()))

        users = list(user_hist_inter_dict.keys())
        items = list(item_hist_inter_dict.keys())

        self.user_name_dict = user_name_dict
        self.item_name_dict = item_name_dict
        self.user_hist_inter_dict = user_hist_inter_dict
        self.item_hist_inter_dict = item_hist_inter_dict
        self.users = users
        self.items = items
        self.user_num = len(users)
        self.item_num = len(items)
        return True
    
    def get_user_item_feature_matrix(self,):
        # exclude test data from the sentiment data to construct matrix
        train_u_i_set = set()
        for user, items in self.user_hist_inter_dict.items():
            items = items[:-test_length]
            for item in items:
                train_u_i_set.add((user, item))

        self.item_feature_matrix,self.item_features= get_item_matrix(self.item_name_dict,self.items_list)
        self.user_feature_matrix = get_user_matrix(self.item_feature_matrix,self.inv_user_name_dict,self.item_name_dict)
        
        return True
    def sample_training(self):
        print('======================= sample training data =======================')
        # print(self.user_feature_matrix.shape, self.item_feature_matrix.shape)
        training_data = []
        training_pairs = np.loadtxt(save_path+'training_data.txt',dtype=str)
        for pair in training_pairs:
          training_data.append([self.user_name_dict[pair[0]],self.item_name_dict[pair[1]],int(pair[2])])
        print('# training samples :', len(training_data))
        self.training_data = np.array(training_data)
        return True
    
    def sample_test(self):
        print('======================= sample test data =======================')
        user_item_label_list = []  # [[u, [item1, item2, ...], [l1, l2, ...]], ...]
        with open(save_path+'test_data.pickle', 'rb') as f:
            test_pairs= pickle.load(f)
        for user_id in test_pairs.keys():
          user=self.user_name_dict[user_id]
          items_ids=test_pairs[user_id][0]
          labels=test_pairs[user_id][1]
          items=np.array([self.item_name_dict[item] for item in items_ids])
          labels=np.array([float(label) for label in labels])
          user_item_label_list.append([user,items,labels])
        print('# test samples :', len(user_item_label_list))
        self.test_data = np.array(user_item_label_list)
        return True
    # def sample_training(self):
    #     print('======================= sample training data =======================')
    #     # print(self.user_feature_matrix.shape, self.item_feature_matrix.shape)
    #     training_data = []
    #     item_set = set(self.items)
    #     for user, items in self.user_hist_inter_dict.items():
    #         if len(items)>9:
    #           items = items[:-(test_length)]
    #           training_pairs = sample_training_pairs(
    #               user, 
    #               items, 
    #               item_set, 
    #               sample_ratio)
    #           for pair in training_pairs:
    #               training_data.append(pair)
    #     print('# training samples :', len(training_data))
    #     self.training_data = np.array(training_data)
    #     return True
    
    # def sample_test(self):
    #     print('======================= sample test data =======================')
    #     user_item_label_list = []  # [[u, [item1, item2, ...], [l1, l2, ...]], ...]
    #     for user, items in self.user_hist_inter_dict.items():
    #       if len(items)>9:
    #         items = items[-(test_length):]
    #         user_item_label_list.append([user, items, np.ones(len(items))])  # add the test items
    #         neg_length=len(items)*10
    #         negative_items = [item for item in self.items if 
    #             item not in self.user_hist_inter_dict[user]]  # the not interacted items
    #         negative_items = np.random.choice(np.array(negative_items), neg_length, replace=False)
    #         user_item_label_list[-1][1] = np.concatenate((user_item_label_list[-1][1], negative_items), axis=0)
    #         user_item_label_list[-1][2] = np.concatenate((user_item_label_list[-1][2], np.zeros(neg_length)), axis=0)
    #     print('# test samples :', len(user_item_label_list))
    #     self.test_data = np.array(user_item_label_list)
    #     return True

    def save(self, save_path):
        return True
    
    def load(self):
        return False

# %%
def amazon_preprocessing():
    rec_dataset = AmazonDataset()
    return rec_dataset

# %%
def dataset_init():
	if dataset == "yelp":
		rec_dataset = yelp_preprocessing()
	elif dataset == "cell_phones" or "kindle_store" or "electronic" or "cds_and_vinyl":
		rec_dataset = amazon_preprocessing()
	return rec_dataset

# %%
dataset="cell_phones"
gpu=True
cuda='0'
weight_decay=0.00001
lr=0.01
epochs=240
batch_size=64
rec_k=5

# %%
import numpy as np
from torch.utils.data import Dataset
class UserItemInterDataset(Dataset):
    def __init__(self, data, user_feature_matrix, item_feature_matrix):
        self.data = data
        self.user_feature_matrix = user_feature_matrix
        self.item_feature_matrix = item_feature_matrix

    def __getitem__(self, index):
        user = self.data[index][0]
        item = self.data[index][1]
        label = self.data[index][2]
        user_feature = self.user_feature_matrix[user]
        item_feature = self.item_feature_matrix[item]
        return user_feature, item_feature, label
    def __len__(self):
        return len(self.data)

# %% [markdown]
# # Train Black-box Model...

# %%
import numpy as np
import torch
from sklearn.metrics import ndcg_score

# %%
def compute_ndcg(test_data, user_feature_matrix, item_feature_matrix, k, model, device):
    model.eval()
    ndcgs = []
    with torch.no_grad():
        for row in test_data:
            user = row[0]
            items = row[1]
            gt_labels = row[2]
            user_features = np.array([user_feature_matrix[user] for i in range(len(items))])
            item_features = np.array([item_feature_matrix[item] for item in items])
            scores = model(torch.from_numpy(user_features).to(device),
                                    torch.from_numpy(item_features).to(device)).squeeze()
            scores = np.array(scores.to('cpu'))
            ndcg = ndcg_score([gt_labels], [scores], k=k)
            ndcgs.append(ndcg)
    ave_ndcg = np.mean(ndcgs)
    return ave_ndcg

# %%
import torch
import numpy as np
import os
import tqdm
import pickle
from pathlib import Path
from torch.utils.data import DataLoader

# %%
from numpy import core

class BaseRecModel(torch.nn.Module):
    def __init__(self, feature_length):
        super(BaseRecModel, self).__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(feature_length * 2, 512),
            torch.nn.ReLU(),
            torch.nn.Linear(512, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 1),
            torch.nn.Sigmoid()
        )

    def forward(self, user_feature, item_feature):
        fusion = torch.cat((user_feature, item_feature), 1)
        out = self.fc(fusion)
        return out

# %%
if gpu:
  device = torch.device('cuda:%s' % cuda)
else:
  device = 'cpu'
print(device)
# Out:
# cuda:0

# %%
rec_dataset = dataset_init()
# Out:
# 1945
# ----- get items matrix -------
# 1945
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# ----- get users matrix -------
# 6794
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# ======================= sample training data =======================
# # training samples : 2871
# ======================= sample test data =======================
# # test samples : 93
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
rec_dataset.item_feature_matrix.shape
# Out:
# (1945, 2304)

# %%
with open(os.path.join(save_path, dataset + "_dataset_obj.pickle"), 'rb') as inp:
  rec_dataset = pickle.load(inp)

# %%
def train_base_recommendation():
    if gpu:
        device = torch.device('cuda:%s' % cuda)
    else:
        device = 'cpu'
    Path(save_path).mkdir(parents=True, exist_ok=True)
    with open(os.path.join(save_path,dataset + "_dataset_obj.pickle"), 'wb') as outp:
        pickle.dump(rec_dataset, outp, pickle.HIGHEST_PROTOCOL)

    train_loader = DataLoader(dataset=UserItemInterDataset(rec_dataset.training_data, 
                                rec_dataset.user_feature_matrix, 
                                rec_dataset.item_feature_matrix),
                          batch_size=batch_size,
                          shuffle=True)

    model = BaseRecModel(rec_dataset.feature_num).to(device)
    loss_fn = torch.nn.BCELoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)

    out_path = os.path.join("./logs", dataset + "_logs")
    Path(out_path).mkdir(parents=True, exist_ok=True)

    ndcg = compute_ndcg(rec_dataset.test_data, 
            rec_dataset.user_feature_matrix, 
            rec_dataset.item_feature_matrix, 
            rec_k, 
            model, 
            device)
    print('init ndcg:', ndcg)
    for epoch in tqdm.trange(epochs):
        model.train()
        optimizer.zero_grad()
        losses = []
        for user_behaviour_feature, item_aspect_feature, label in train_loader:
            user_behaviour_feature = user_behaviour_feature.to(device)
            item_aspect_feature = item_aspect_feature.to(device)
            label = label.float().to(device)
            out = model(user_behaviour_feature, item_aspect_feature).squeeze()
            loss = loss_fn(out, label)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            losses.append(loss.to('cpu').detach().numpy())
            ave_train = np.mean(np.array(losses))
        print('epoch %d: ' % epoch, 'training loss: ', ave_train)
        # compute necg
        if epoch % 10 == 0:
            ndcg = compute_ndcg(rec_dataset.test_data, 
            rec_dataset.user_feature_matrix, 
            rec_dataset.item_feature_matrix, 
            rec_k, 
            model, 
            device)
            print('epoch %d: ' % epoch, 'training loss: ', ave_train, 'NDCG: ', ndcg)
    torch.save(model.state_dict(), os.path.join(save_path, "model.model"))
    return rec_dataset


if __name__ == "__main__":
    torch.manual_seed(0)
    np.random.seed(0)
    if gpu:
        os.environ["CUDA_VISIBLE_DEVICES"] =cuda
        print("Using CUDA",cuda)
    else:
        print("Using CPU")
    rec_dataset=train_base_recommendation()
# Out:
# Using CUDA 0
# init ndcg: 0.07731034104130662
#   0%|          | 0/240 [00:00<?, ?it/s]
# epoch 0:  training loss:  0.6559843
#   0%|          | 1/240 [00:00<02:20,  1.71it/s]
# epoch 0:  training loss:  0.6559843 NDCG:  0.08904614145749981
#   1%|          | 2/240 [00:00<01:34,  2.53it/s]
# epoch 1:  training loss:  0.6366049
#   1%|▏         | 3/240 [00:01<01:16,  3.11it/s]
# epoch 2:  training loss:  0.6350551
#   2%|▏         | 4/240 [00:01<01:09,  3.40it/s]
# epoch 3:  training loss:  0.6342837
#   2%|▏         | 5/240 [00:01<01:03,  3.72it/s]
# epoch 4:  training loss:  0.6332564
#   2%|▎         | 6/240 [00:01<00:59,  3.94it/s]
# epoch 5:  training loss:  0.63218343
#   3%|▎         | 7/240 [00:02<00:56,  4.12it/s]
# epoch 6:  training loss:  0.63148654
#   3%|▎         | 8/240 [00:02<00:55,  4.19it/s]
# epoch 7:  training loss:  0.63044715
#   4%|▍         | 9/240 [00:02<00:56,  4.12it/s]
# epoch 8:  training loss:  0.62933797
#   4%|▍         | 10/240 [00:02<00:55,  4.11it/s]
# epoch 9:  training loss:  0.6282087
# epoch 10:  training loss:  0.62691575
#   5%|▍         | 11/240 [00:03<01:15,  3.03it/s]
# epoch 10:  training loss:  0.62691575 NDCG:  0.22428561723041499
#   5%|▌         | 12/240 [00:03<01:07,  3.35it/s]
# epoch 11:  training loss:  0.625341
#   5%|▌         | 13/240 [00:03<01:02,  3.63it/s]
# epoch 12:  training loss:  0.62412286
#   6%|▌         | 14/240 [00:03<00:58,  3.89it/s]
# epoch 13:  training loss:  0.62280476
#   6%|▋         | 15/240 [00:04<00:54,  4.11it/s]
# epoch 14:  training loss:  0.62134904
#   7%|▋         | 16/240 [00:04<00:54,  4.13it/s]
# epoch 15:  training loss:  0.6195056
#   7%|▋         | 17/240 [00:04<00:52,  4.28it/s]
# epoch 16:  training loss:  0.61726743
#   8%|▊         | 18/240 [00:04<00:51,  4.32it/s]
# epoch 17:  training loss:  0.61640984
#   8%|▊         | 19/240 [00:05<00:52,  4.22it/s]
# epoch 18:  training loss:  0.6146805
#   8%|▊         | 20/240 [00:05<00:52,  4.21it/s]
# epoch 19:  training loss:  0.6118428
# epoch 20:  training loss:  0.6098647
#   9%|▉         | 21/240 [00:05<01:08,  3.21it/s]
# epoch 20:  training loss:  0.6098647 NDCG:  0.2278696250066917
#   9%|▉         | 22/240 [00:06<01:02,  3.49it/s]
# epoch 21:  training loss:  0.60771394
#  10%|▉         | 23/240 [00:06<00:58,  3.69it/s]
# epoch 22:  training loss:  0.6051721
#  10%|█         | 24/240 [00:06<00:56,  3.84it/s]
# epoch 23:  training loss:  0.6031347
#  10%|█         | 25/240 [00:06<00:53,  3.99it/s]
# epoch 24:  training loss:  0.5993265
#  11%|█         | 26/240 [00:06<00:51,  4.15it/s]
# epoch 25:  training loss:  0.59763217
#  11%|█▏        | 27/240 [00:07<00:51,  4.16it/s]
# epoch 26:  training loss:  0.59504855
#  12%|█▏        | 28/240 [00:07<00:50,  4.22it/s]
# epoch 27:  training loss:  0.59245473
#  12%|█▏        | 29/240 [00:07<00:49,  4.30it/s]
# epoch 28:  training loss:  0.5896407
#  12%|█▎        | 30/240 [00:07<00:48,  4.32it/s]
# epoch 29:  training loss:  0.5874632
# epoch 30:  training loss:  0.5842192
#  13%|█▎        | 31/240 [00:08<01:03,  3.27it/s]
# epoch 30:  training loss:  0.5842192 NDCG:  0.2370903680016749
#  13%|█▎        | 32/240 [00:08<01:00,  3.46it/s]
# epoch 31:  training loss:  0.58108675
#  14%|█▍        | 33/240 [00:08<00:55,  3.71it/s]
# epoch 32:  training loss:  0.57764804
#  14%|█▍        | 34/240 [00:09<00:52,  3.90it/s]
# epoch 33:  training loss:  0.5767197
#  15%|█▍        | 35/240 [00:09<00:50,  4.05it/s]
# epoch 34:  training loss:  0.5722899
#  15%|█▌        | 36/240 [00:09<00:49,  4.11it/s]
# epoch 35:  training loss:  0.5701174
#  15%|█▌        | 37/240 [00:09<00:48,  4.18it/s]
# epoch 36:  training loss:  0.56783366
#  16%|█▌        | 38/240 [00:09<00:47,  4.26it/s]
# epoch 37:  training loss:  0.5644155
#  16%|█▋        | 39/240 [00:10<00:48,  4.12it/s]
# epoch 38:  training loss:  0.5643587
#  17%|█▋        | 40/240 [00:10<00:48,  4.16it/s]
# epoch 39:  training loss:  0.56045276
# epoch 40:  training loss:  0.5556122
#  17%|█▋        | 41/240 [00:10<01:02,  3.17it/s]
# epoch 40:  training loss:  0.5556122 NDCG:  0.24337287767232893
#  18%|█▊        | 42/240 [00:11<00:57,  3.42it/s]
# epoch 41:  training loss:  0.5570251
#  18%|█▊        | 43/240 [00:11<00:54,  3.62it/s]
# epoch 42:  training loss:  0.5508098
#  18%|█▊        | 44/240 [00:11<00:51,  3.80it/s]
# epoch 43:  training loss:  0.54837817
#  19%|█▉        | 45/240 [00:11<00:48,  3.98it/s]
# epoch 44:  training loss:  0.54394525
#  19%|█▉        | 46/240 [00:12<00:46,  4.14it/s]
# epoch 45:  training loss:  0.54389817
#  20%|██        | 48/240 [00:12<00:42,  4.55it/s]
# epoch 46:  training loss:  0.5430806
# epoch 47:  training loss:  0.54080117
#  20%|██        | 49/240 [00:12<00:41,  4.64it/s]
# epoch 48:  training loss:  0.53772545
#  21%|██        | 50/240 [00:12<00:42,  4.44it/s]
# epoch 49:  training loss:  0.5330241
# epoch 50:  training loss:  0.5298495
#  21%|██▏       | 51/240 [00:13<00:56,  3.36it/s]
# epoch 50:  training loss:  0.5298495 NDCG:  0.2618063692540938
#  22%|██▏       | 52/240 [00:13<00:51,  3.63it/s]
# epoch 51:  training loss:  0.52634436
#  22%|██▏       | 53/240 [00:13<00:49,  3.78it/s]
# epoch 52:  training loss:  0.5224576
#  22%|██▎       | 54/240 [00:14<00:50,  3.67it/s]
# epoch 53:  training loss:  0.5221452
#  23%|██▎       | 55/240 [00:14<00:49,  3.70it/s]
# epoch 54:  training loss:  0.52260864
#  23%|██▎       | 56/240 [00:14<00:52,  3.50it/s]
# epoch 55:  training loss:  0.519084
#  24%|██▍       | 57/240 [00:15<00:57,  3.18it/s]
# epoch 56:  training loss:  0.51691777
#  24%|██▍       | 58/240 [00:15<01:03,  2.88it/s]
# epoch 57:  training loss:  0.51588005
#  25%|██▍       | 59/240 [00:15<00:59,  3.04it/s]
# epoch 58:  training loss:  0.5096834
#  25%|██▌       | 60/240 [00:16<00:59,  3.00it/s]
# epoch 59:  training loss:  0.50604415
# epoch 60:  training loss:  0.5046773
#  25%|██▌       | 61/240 [00:17<01:28,  2.02it/s]
# epoch 60:  training loss:  0.5046773 NDCG:  0.2819376457699049
#  26%|██▌       | 62/240 [00:17<01:24,  2.11it/s]
# epoch 61:  training loss:  0.50321645
#  26%|██▋       | 63/240 [00:17<01:14,  2.36it/s]
# epoch 62:  training loss:  0.5090624
#  27%|██▋       | 65/240 [00:18<00:56,  3.11it/s]
# epoch 63:  training loss:  0.49168006
# epoch 64:  training loss:  0.48918712
#  28%|██▊       | 67/240 [00:18<00:40,  4.30it/s]
# epoch 65:  training loss:  0.48831847
# epoch 66:  training loss:  0.48680016
#  29%|██▉       | 69/240 [00:18<00:32,  5.25it/s]
# epoch 67:  training loss:  0.49218366
# epoch 68:  training loss:  0.48096052
#  29%|██▉       | 70/240 [00:18<00:30,  5.64it/s]
# epoch 69:  training loss:  0.4840072
# epoch 70:  training loss:  0.47810465
#  30%|██▉       | 71/240 [00:19<00:37,  4.47it/s]
# epoch 70:  training loss:  0.47810465 NDCG:  0.29091009335652457
#  30%|███       | 73/240 [00:19<00:32,  5.16it/s]
# epoch 71:  training loss:  0.479787
# epoch 72:  training loss:  0.48126686
#  31%|███       | 74/240 [00:19<00:34,  4.82it/s]
# epoch 73:  training loss:  0.4612952
#  31%|███▏      | 75/240 [00:20<00:34,  4.72it/s]
# epoch 74:  training loss:  0.46222398
#  32%|███▏      | 76/240 [00:20<00:39,  4.13it/s]
# epoch 75:  training loss:  0.4599989
#  32%|███▏      | 77/240 [00:20<00:46,  3.49it/s]
# epoch 76:  training loss:  0.4612971
#  32%|███▎      | 78/240 [00:21<00:47,  3.44it/s]
# epoch 77:  training loss:  0.4691077
#  33%|███▎      | 79/240 [00:21<00:51,  3.11it/s]
# epoch 78:  training loss:  0.45463863
#  33%|███▎      | 80/240 [00:21<00:57,  2.78it/s]
# epoch 79:  training loss:  0.45895654
# epoch 80:  training loss:  0.44757903
#  34%|███▍      | 81/240 [00:22<01:21,  1.96it/s]
# epoch 80:  training loss:  0.44757903 NDCG:  0.3087299035323336
#  34%|███▍      | 82/240 [00:23<01:15,  2.09it/s]
# epoch 81:  training loss:  0.44914037
#  35%|███▍      | 83/240 [00:23<01:11,  2.19it/s]
# epoch 82:  training loss:  0.46183586
#  35%|███▌      | 84/240 [00:23<01:01,  2.55it/s]
# epoch 83:  training loss:  0.43950114
#  35%|███▌      | 85/240 [00:24<00:54,  2.86it/s]
# epoch 84:  training loss:  0.43316528
#  36%|███▌      | 86/240 [00:24<00:48,  3.19it/s]
# epoch 85:  training loss:  0.4346923
#  36%|███▋      | 87/240 [00:24<00:43,  3.51it/s]
# epoch 86:  training loss:  0.452036
#  37%|███▋      | 88/240 [00:24<00:40,  3.78it/s]
# epoch 87:  training loss:  0.4353205
#  37%|███▋      | 89/240 [00:25<00:38,  3.91it/s]
# epoch 88:  training loss:  0.42705333
#  38%|███▊      | 90/240 [00:25<00:36,  4.11it/s]
# epoch 89:  training loss:  0.43626645
# epoch 90:  training loss:  0.41913956
#  38%|███▊      | 91/240 [00:25<00:45,  3.24it/s]
# epoch 90:  training loss:  0.41913956 NDCG:  0.30095865252518306
#  38%|███▊      | 92/240 [00:25<00:42,  3.49it/s]
# epoch 91:  training loss:  0.43031722
#  39%|███▉      | 93/240 [00:26<00:42,  3.43it/s]
# epoch 92:  training loss:  0.43032938
#  39%|███▉      | 94/240 [00:26<00:40,  3.57it/s]
# epoch 93:  training loss:  0.41695106
#  40%|███▉      | 95/240 [00:26<00:38,  3.80it/s]
# epoch 94:  training loss:  0.41301563
#  40%|████      | 96/240 [00:26<00:36,  3.98it/s]
# epoch 95:  training loss:  0.41155073
#  40%|████      | 97/240 [00:27<00:34,  4.14it/s]
# epoch 96:  training loss:  0.41692406
#  41%|████      | 98/240 [00:27<00:33,  4.25it/s]
# epoch 97:  training loss:  0.3903146
#  41%|████▏     | 99/240 [00:27<00:32,  4.32it/s]
# epoch 98:  training loss:  0.42191985
#  42%|████▏     | 100/240 [00:27<00:32,  4.35it/s]
# epoch 99:  training loss:  0.40901834
# epoch 100:  training loss:  0.40936852
#  42%|████▏     | 101/240 [00:28<00:42,  3.26it/s]
# epoch 100:  training loss:  0.40936852 NDCG:  0.3107498755477088
#  42%|████▎     | 102/240 [00:28<00:40,  3.38it/s]
# epoch 101:  training loss:  0.42588884
#  43%|████▎     | 103/240 [00:28<00:37,  3.63it/s]
# epoch 102:  training loss:  0.39845535
#  43%|████▎     | 104/240 [00:29<00:35,  3.79it/s]
# epoch 103:  training loss:  0.40244
#  44%|████▍     | 105/240 [00:29<00:33,  4.00it/s]
# epoch 104:  training loss:  0.39932865
#  45%|████▍     | 107/240 [00:29<00:29,  4.51it/s]
# epoch 105:  training loss:  0.41523197
# epoch 106:  training loss:  0.40553096
#  45%|████▌     | 108/240 [00:29<00:26,  4.97it/s]
# epoch 107:  training loss:  0.38465422
#  45%|████▌     | 109/240 [00:30<00:28,  4.55it/s]
# epoch 108:  training loss:  0.38000238
#  46%|████▌     | 110/240 [00:30<00:29,  4.40it/s]
# epoch 109:  training loss:  0.37290955
# epoch 110:  training loss:  0.3930898
#  47%|████▋     | 112/240 [00:30<00:33,  3.79it/s]
# epoch 110:  training loss:  0.3930898 NDCG:  0.32187189928494353
# epoch 111:  training loss:  0.3827937
#  47%|████▋     | 113/240 [00:31<00:29,  4.32it/s]
# epoch 112:  training loss:  0.38525683
#  48%|████▊     | 114/240 [00:31<00:29,  4.29it/s]
# epoch 113:  training loss:  0.37280816
#  48%|████▊     | 115/240 [00:31<00:28,  4.33it/s]
# epoch 114:  training loss:  0.3925651
#  48%|████▊     | 116/240 [00:31<00:28,  4.35it/s]
# epoch 115:  training loss:  0.3632952
#  49%|████▉     | 117/240 [00:32<00:28,  4.39it/s]
# epoch 116:  training loss:  0.37438062
#  49%|████▉     | 118/240 [00:32<00:28,  4.26it/s]
# epoch 117:  training loss:  0.3759567
#  50%|████▉     | 119/240 [00:32<00:27,  4.33it/s]
# epoch 118:  training loss:  0.34566367
#  50%|█████     | 120/240 [00:32<00:27,  4.39it/s]
# epoch 119:  training loss:  0.39201164
# epoch 120:  training loss:  0.36662903
#  50%|█████     | 121/240 [00:33<00:35,  3.37it/s]
# epoch 120:  training loss:  0.36662903 NDCG:  0.329753277586806
#  51%|█████▏    | 123/240 [00:33<00:29,  3.94it/s]
# epoch 121:  training loss:  0.37571254
# epoch 122:  training loss:  0.386705
#  52%|█████▏    | 125/240 [00:33<00:24,  4.66it/s]
# epoch 123:  training loss:  0.35439774
# epoch 124:  training loss:  0.35738134
#  52%|█████▎    | 126/240 [00:34<00:22,  5.10it/s]
# epoch 125:  training loss:  0.34376857
#  53%|█████▎    | 127/240 [00:34<00:23,  4.89it/s]
# epoch 126:  training loss:  0.35447735
#  53%|█████▎    | 128/240 [00:34<00:23,  4.81it/s]
# epoch 127:  training loss:  0.3612941
#  54%|█████▍    | 129/240 [00:34<00:25,  4.43it/s]
# epoch 128:  training loss:  0.34847474
#  54%|█████▍    | 130/240 [00:35<00:25,  4.32it/s]
# epoch 129:  training loss:  0.36162597
# epoch 130:  training loss:  0.35005978
#  55%|█████▍    | 131/240 [00:35<00:35,  3.11it/s]
# epoch 130:  training loss:  0.35005978 NDCG:  0.326089360975312
#  55%|█████▌    | 132/240 [00:35<00:33,  3.23it/s]
# epoch 131:  training loss:  0.3462741
#  55%|█████▌    | 133/240 [00:36<00:32,  3.26it/s]
# epoch 132:  training loss:  0.3363633
#  56%|█████▌    | 134/240 [00:36<00:31,  3.32it/s]
# epoch 133:  training loss:  0.33202776
#  56%|█████▋    | 135/240 [00:36<00:29,  3.56it/s]
# epoch 134:  training loss:  0.3305079
#  57%|█████▋    | 136/240 [00:36<00:27,  3.77it/s]
# epoch 135:  training loss:  0.3450936
#  57%|█████▋    | 137/240 [00:37<00:26,  3.90it/s]
# epoch 136:  training loss:  0.34005508
#  57%|█████▊    | 138/240 [00:37<00:25,  3.94it/s]
# epoch 137:  training loss:  0.34549943
#  58%|█████▊    | 139/240 [00:37<00:24,  4.11it/s]
# epoch 138:  training loss:  0.3345901
#  58%|█████▊    | 140/240 [00:37<00:23,  4.20it/s]
# epoch 139:  training loss:  0.32661918
# epoch 140:  training loss:  0.3378381
#  59%|█████▉    | 142/240 [00:38<00:27,  3.61it/s]
# epoch 140:  training loss:  0.3378381 NDCG:  0.30114012221455055
# epoch 141:  training loss:  0.32687974
#  60%|██████    | 144/240 [00:38<00:19,  4.82it/s]
# epoch 142:  training loss:  0.30695412
# epoch 143:  training loss:  0.30499697
#  61%|██████    | 146/240 [00:39<00:17,  5.38it/s]
# epoch 144:  training loss:  0.31725237
# epoch 145:  training loss:  0.33050227
#  62%|██████▏   | 148/240 [00:39<00:15,  5.87it/s]
# epoch 146:  training loss:  0.32733306
# epoch 147:  training loss:  0.30308357
#  62%|██████▎   | 150/240 [00:39<00:14,  6.39it/s]
# epoch 148:  training loss:  0.33652154
# epoch 149:  training loss:  0.33111772
#  63%|██████▎   | 151/240 [00:40<00:18,  4.91it/s]
# epoch 150:  training loss:  0.29522848
# epoch 150:  training loss:  0.29522848 NDCG:  0.3405321344534416
#  64%|██████▍   | 153/240 [00:40<00:15,  5.66it/s]
# epoch 151:  training loss:  0.3047018
# epoch 152:  training loss:  0.31692863
#  65%|██████▍   | 155/240 [00:40<00:13,  6.18it/s]
# epoch 153:  training loss:  0.31318566
# epoch 154:  training loss:  0.27509367
#  65%|██████▌   | 157/240 [00:41<00:12,  6.51it/s]
# epoch 155:  training loss:  0.30458575
# epoch 156:  training loss:  0.292929
#  66%|██████▋   | 159/240 [00:41<00:12,  6.62it/s]
# epoch 157:  training loss:  0.28962952
# epoch 158:  training loss:  0.2819192
#  67%|██████▋   | 160/240 [00:41<00:11,  6.68it/s]
# epoch 159:  training loss:  0.31146365
# epoch 160:  training loss:  0.29956818
#  68%|██████▊   | 162/240 [00:41<00:14,  5.48it/s]
# epoch 160:  training loss:  0.29956818 NDCG:  0.34453536610308794
# epoch 161:  training loss:  0.31077382
#  68%|██████▊   | 164/240 [00:42<00:12,  6.12it/s]
# epoch 162:  training loss:  0.2830786
# epoch 163:  training loss:  0.2616557
#  69%|██████▉   | 166/240 [00:42<00:11,  6.40it/s]
# epoch 164:  training loss:  0.28758764
# epoch 165:  training loss:  0.28547114
#  70%|███████   | 168/240 [00:42<00:11,  6.45it/s]
# epoch 166:  training loss:  0.3074325
# epoch 167:  training loss:  0.30125028
#  71%|███████   | 170/240 [00:43<00:10,  6.64it/s]
# epoch 168:  training loss:  0.28790602
# epoch 169:  training loss:  0.27654502
#  71%|███████▏  | 171/240 [00:43<00:13,  5.08it/s]
# epoch 170:  training loss:  0.27750453
# epoch 170:  training loss:  0.27750453 NDCG:  0.3374773801100938
#  72%|███████▏  | 173/240 [00:43<00:11,  5.78it/s]
# epoch 171:  training loss:  0.2722199
# epoch 172:  training loss:  0.24927747
#  73%|███████▎  | 175/240 [00:43<00:10,  6.33it/s]
# epoch 173:  training loss:  0.29379332
# epoch 174:  training loss:  0.2833095
#  74%|███████▍  | 177/240 [00:44<00:09,  6.60it/s]
# epoch 175:  training loss:  0.2932887
# epoch 176:  training loss:  0.2697788
#  75%|███████▍  | 179/240 [00:44<00:09,  6.76it/s]
# epoch 177:  training loss:  0.24739315
# epoch 178:  training loss:  0.2594655
#  75%|███████▌  | 180/240 [00:44<00:08,  6.71it/s]
# epoch 179:  training loss:  0.25828162
# epoch 180:  training loss:  0.29005054
#  76%|███████▌  | 182/240 [00:45<00:10,  5.48it/s]
# epoch 180:  training loss:  0.29005054 NDCG:  0.3440670164999059
# epoch 181:  training loss:  0.26054817
#  77%|███████▋  | 184/240 [00:45<00:09,  6.18it/s]
# epoch 182:  training loss:  0.25255573
# epoch 183:  training loss:  0.264631
#  78%|███████▊  | 186/240 [00:45<00:08,  6.44it/s]
# epoch 184:  training loss:  0.25162128
# epoch 185:  training loss:  0.26256305
#  78%|███████▊  | 188/240 [00:46<00:07,  6.68it/s]
# epoch 186:  training loss:  0.2738304
# epoch 187:  training loss:  0.2591705
#  79%|███████▉  | 190/240 [00:46<00:07,  6.76it/s]
# epoch 188:  training loss:  0.22291541
# epoch 189:  training loss:  0.23511198
#  80%|███████▉  | 191/240 [00:46<00:09,  5.14it/s]
# epoch 190:  training loss:  0.26912412
# epoch 190:  training loss:  0.26912412 NDCG:  0.34708713344325204
#  80%|████████  | 192/240 [00:46<00:08,  5.52it/s]
# epoch 191:  training loss:  0.2548068
#  80%|████████  | 193/240 [00:47<00:09,  4.91it/s]
# epoch 192:  training loss:  0.24220791
#  81%|████████▏ | 195/240 [00:47<00:08,  5.38it/s]
# epoch 193:  training loss:  0.27543673
# epoch 194:  training loss:  0.25131673
#  82%|████████▏ | 196/240 [00:47<00:08,  5.25it/s]
# epoch 195:  training loss:  0.25404567
#  82%|████████▏ | 197/240 [00:47<00:09,  4.73it/s]
# epoch 196:  training loss:  0.23448215
#  82%|████████▎ | 198/240 [00:48<00:12,  3.48it/s]
# epoch 197:  training loss:  0.21454388
#  83%|████████▎ | 199/240 [00:48<00:13,  3.04it/s]
# epoch 198:  training loss:  0.25039837
#  83%|████████▎ | 200/240 [00:48<00:11,  3.37it/s]
# epoch 199:  training loss:  0.27580163
# epoch 200:  training loss:  0.23305058
#  84%|████████▍ | 201/240 [00:49<00:13,  2.83it/s]
# epoch 200:  training loss:  0.23305058 NDCG:  0.33677719821215873
#  84%|████████▍ | 202/240 [00:49<00:13,  2.80it/s]
# epoch 201:  training loss:  0.24144618
#  85%|████████▍ | 203/240 [00:50<00:13,  2.79it/s]
# epoch 202:  training loss:  0.20424683
#  85%|████████▌ | 204/240 [00:50<00:11,  3.15it/s]
# epoch 203:  training loss:  0.23504208
#  85%|████████▌ | 205/240 [00:50<00:10,  3.43it/s]
# epoch 204:  training loss:  0.20851834
#  86%|████████▌ | 206/240 [00:50<00:09,  3.66it/s]
# epoch 205:  training loss:  0.24117525
#  86%|████████▋ | 207/240 [00:51<00:08,  3.86it/s]
# epoch 206:  training loss:  0.25066337
#  87%|████████▋ | 208/240 [00:51<00:08,  3.96it/s]
# epoch 207:  training loss:  0.21725246
#  87%|████████▋ | 209/240 [00:51<00:07,  4.03it/s]
# epoch 208:  training loss:  0.23174074
#  88%|████████▊ | 210/240 [00:51<00:07,  4.15it/s]
# epoch 209:  training loss:  0.2118329
# epoch 210:  training loss:  0.21854992
#  88%|████████▊ | 211/240 [00:52<00:08,  3.23it/s]
# epoch 210:  training loss:  0.21854992 NDCG:  0.3329187287950759
#  88%|████████▊ | 212/240 [00:52<00:07,  3.53it/s]
# epoch 211:  training loss:  0.20048466
#  89%|████████▉ | 213/240 [00:52<00:07,  3.75it/s]
# epoch 212:  training loss:  0.20314778
#  89%|████████▉ | 214/240 [00:52<00:06,  3.89it/s]
# epoch 213:  training loss:  0.19081813
#  90%|█████████ | 216/240 [00:53<00:05,  4.28it/s]
# epoch 214:  training loss:  0.19477747
# epoch 215:  training loss:  0.24233654
#  91%|█████████ | 218/240 [00:53<00:04,  5.23it/s]
# epoch 216:  training loss:  0.225229
# epoch 217:  training loss:  0.2202788
#  92%|█████████▏| 220/240 [00:53<00:03,  5.81it/s]
# epoch 218:  training loss:  0.19391556
# epoch 219:  training loss:  0.20334499
#  92%|█████████▏| 221/240 [00:54<00:04,  4.62it/s]
# epoch 220:  training loss:  0.23643221
# epoch 220:  training loss:  0.23643221 NDCG:  0.34787766766561323
#  93%|█████████▎| 223/240 [00:54<00:03,  5.44it/s]
# epoch 221:  training loss:  0.20165884
# epoch 222:  training loss:  0.19661492
#  94%|█████████▍| 225/240 [00:54<00:02,  5.85it/s]
# epoch 223:  training loss:  0.17188874
# epoch 224:  training loss:  0.17336611
#  95%|█████████▍| 227/240 [00:55<00:02,  6.15it/s]
# epoch 225:  training loss:  0.22687244
# epoch 226:  training loss:  0.23375416
#  95%|█████████▌| 229/240 [00:55<00:01,  6.27it/s]
# epoch 227:  training loss:  0.1877829
# epoch 228:  training loss:  0.1736302
#  96%|█████████▌| 230/240 [00:55<00:01,  6.35it/s]
# epoch 229:  training loss:  0.19657086
# epoch 230:  training loss:  0.15822601
#  96%|█████████▋| 231/240 [00:56<00:02,  4.20it/s]
# epoch 230:  training loss:  0.15822601 NDCG:  0.3428547115880152
#  97%|█████████▋| 233/240 [00:56<00:01,  4.49it/s]
# epoch 231:  training loss:  0.2205112
# epoch 232:  training loss:  0.2126118
#  98%|█████████▊| 235/240 [00:56<00:01,  4.85it/s]
# epoch 233:  training loss:  0.17146191
# epoch 234:  training loss:  0.24441206
#  99%|█████████▉| 237/240 [00:57<00:00,  5.61it/s]
# epoch 235:  training loss:  0.18343328
# epoch 236:  training loss:  0.16697739
# 100%|█████████▉| 239/240 [00:57<00:00,  6.05it/s]
# epoch 237:  training loss:  0.16849056
# epoch 238:  training loss:  0.21604227
# 100%|██████████| 240/240 [00:57<00:00,  4.16it/s]
# epoch 239:  training loss:  0.24283147

# %%
dataset="cell_phones"
base_model_path="/content/drive/MyDrive/cell_phone/"
gpu=True
cuda='0'
data_obj_path="/content/drive/MyDrive/cell_phone/"
rec_k=5
lam=100
gam=0.7
alp=0.2
user_mask=False
lr=0.01
step=500
mask_thresh=0.1
test_num=-1
# save_path="./explanation_objs/"

# %%
import torch
import pickle
import os
from pathlib import Path

# %% [markdown]
# # User Perspective Features

# %%
import json
import nltk

# %%
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
def lemmatization(text):
    result=[]
    wordnet = WordNetLemmatizer()
    for token,tag in pos_tag(text):
        pos=tag[0].lower()
        if pos not in ['a', 'r', 'n', 'v']:
            pos='n'
        # if pos in ['n','a']:   
        #   result.append(wordnet.lemmatize(token,pos))
    return result
def remove_stopwords(text):
    en_stopwords = stopwords.words('english')
    en_stopwords+=['may','could','that','without','iii','with','and','This','That','Those','These']
    result = []
    for token in text:
        if token not in en_stopwords:
            result.append(token)
            
    return result
def remove_punct(text):
    tokenizer = RegexpTokenizer(r"\w+")
    lst=tokenizer.tokenize(' '.join(text))
    return lst

def remove_tag(text):
    text=' '.join(text)
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

def preprocess(text):
  chars=['&','%','#','@','^','>','<','\n','\\','\t',';','"','/']
  stwords=stopwords.words('english')
  for ch in chars:
    text=text.replace(ch,' ')
  text=" ".join(text.split())
  # text=text.lower()
  text_tokenized=word_tokenize(text)
  cleaned_text= remove_stopwords(text_tokenized)
  cleaned_text= remove_punct(cleaned_text)
  # cleaned_text=lemmatization(cleaned_text)
  cleaned_text=remove_tag(cleaned_text)
  cleaned_text=remove_urls(cleaned_text)
  cleaned_text=''.join([i for i in cleaned_text ])
  cleaned_text=[word for word in cleaned_text.split(' ') if len(word)>1]
  # print(cleaned_text)
  return ' '.join(cleaned_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
def preprocess_text_first(text):
  list_to_replace=['br','mso','gte','xml','false','!','-','\'','\"','[',']','/','\\n','\\','span','a-size-base','a-color-secondary','input type','header name','value','=','<a href= javascript:void(0) class= ','{','}','class=','header','<a href= javascript:void(0)','<','>','href',')','(',';','quot','&',':','javascript']
  for char in list_to_replace:
    text=text.replace(char,' ')
  for i in range(15):
    text=text.replace('  ',' ')
  new_text=''
  for word in text.split(' '):
    if len(word)>1 and len(word)<35:
      new_text+=word+' '
  return new_text

# %%
items_list=[]
users_list=[]
review_features={}
f=open(save_path+'Cell_Phones_and_Accessories')
lines=f.readlines()
i=0
for line in lines:
  if i%5000==0:
    print(i)
  i+=1
  user_id = line.split('@')[0]
  item_id = line.split('@')[1]
  if item_id in df_meta['asin'].values:
    users_list.append(user_id)
    items_list.append(item_id)
    l = len(user_id) + len(item_id)
    fosr_data = line[l+3:]
    for seg in fosr_data.split('||'):
      if (user_id,item_id) not in review_features.keys():
        review_features[(user_id,item_id)]=[]
      fos = seg.split(':')[0].strip('|')
      if len(fos.split('|')) > 1:
            feature = fos.split('|')[0]
            opinion = fos.split('|')[1]
            sentiment = fos.split('|')[2]
            sentence= seg.split(':')[1]
            if sentiment=='+1':
              senti=1
            else:
              senti=-1
            review_features[(user_id,item_id)].append([feature,opinion,senti,sentence])
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000

# %%
user_test_perspective={}
i=0
for (user_id , item_id) in review_features.keys():
  review_feature=review_features[(user_id,item_id)]
  if i%5000==0:
    print(i)
  i+=1
  for features in review_feature:
    sentence=features[3]
    sentence=preprocess_text_first(sentence)
    sentence=preprocess(sentence).lower()
    if (user_id , item_id) not in user_test_perspective.keys():
      final_vect=[]
    final_vect+=sentence.split(' ')
    for word in sentence.split(' '):
      # tokens=list(set(df_words[df_words['word']==word]['tokenized'].values))
      # for token in tokens:
        final_vect+=word.split(' ')
    final_vect=list(set(final_vect))
    new_final_vect=[]
    for word in final_vect:
      if len(word)>1:
        new_final_vect.append(word)
    user_test_perspective[(user_id , item_id)]=new_final_vect
# Out:
# 0
# 5000
# 10000
# 15000

# %%
user_test_perspective

# %%
rec_dataset.inv_item_name_dict[622]
# Out:
# 'B00FL6ADNC'

# %% [markdown]
# # Train Explaination Generator Model

# %%
def get_features(item_id):
  item=rec_dataset.item_name_dict[item_id]
  item_features=rec_dataset.item_features[item]
  len_features=0
  features=[]
  th1=len(item_features[0])
  th2=len(item_features[0])+len(item_features[1])
  for i in range(3):
    len_features+=len(item_features[i])
    features+=item_features[i]
  return features,th1,th2

# %%
def get_average_vect_test(weights,tensor_vect):
  weights=torch.FloatTensor(weights).to(device)
  # print(tensor_vect)
  # print(weights)
  weights=torch.transpose(weights.repeat(tensor_vect.shape[1],1),0,1)
  average=torch.mean(weights*tensor_vect,axis=0).to(device)
  return average

# %%
def get_new_item_vector(item_id,th1,th2,new_weights,tensor_vect_desc,tensor_vect_feature,tensor_vect_title):
    # item_id= rec_dataset.inv_item_name_dict[item]
    final_vector=[]
    # print(tensor_vect_desc.shape)
    average_vect_desc=get_average_vect_test(new_weights[0:th1],tensor_vect_desc)
    average_vect_title=get_average_vect_test(new_weights[th1:th2],tensor_vect_title)
    average_vect_feature=get_average_vect_test(new_weights[th2:],tensor_vect_feature)

    final_vector=torch.cat((average_vect_desc,average_vect_title,average_vect_feature))
    
      # final_vect=np.array(final_vector, dtype='float32')
    return final_vector

# %%
def get_random_chromosome(features):
  ch = np.random.choice([0, 1], size=len(features),p=[0.1,0.9])
  # for i in range(10):
  #   rand_num=np.random.randint(0,len(ch))
  #   ch[rand_num]=0
  # ch=np.ones(len(features))
  return ch

# %%
def get_first_population(num_population,features):
  pops=[]
  for i in range(num_population):
    ch=get_random_chromosome(features)
    pops.append(ch)
  return pops

# %%
def select_chrs(dict_chooses,num_population,population):
  new_population=[]
  while len(new_population)<num_population:
    rand_num=np.random.rand()
    for key in dict_chooses.keys():
      if rand_num>=key[0] and rand_num<=key[1]:
        new_population.append(population[dict_chooses[key]])
  return new_population

# %%
alpha=1
lam=10
beta=10

# %%
def calc_fitnesses(margin_score,population,th1,th2,user_id,item_id,base_model,tensor_vect_desc,tensor_vect_title,tensor_vect_feature):
  best_fit=-10000.0
  best_ans=[]
  dict_fitnesses={}
  # print(out_last)
  count=0
  # print(len(population))
  user=rec_dataset.user_name_dict[user_id]
  user_vect=torch.from_numpy(rec_dataset.user_feature_matrix[user]).to(device)
  count_best=0
  for chr in population:
    item_feature_star=get_new_item_vector(item_id,th1,th2,chr,tensor_vect_desc,tensor_vect_feature,tensor_vect_title)
    score = base_model(user_vect.unsqueeze(0), item_feature_star.unsqueeze(0))
    count_features_rate=np.count_nonzero(chr)/len(chr)
    beta=10
    if score.cpu()-margin_score.cpu()>0:
      count_features_rate=(len(chr)-np.count_nonzero(chr))/len(chr)
      beta=0.5
      
    # else:
    #   alpha=100.0
    #   beta=1.0
    # print(margin_score)
    # print(score)
    fitness=1.0/(lam*(((alpha+score.cpu()-margin_score.cpu()))))+(beta*((count_features_rate)))
    # if out_new<0.5:
    #   for rate in [0.8,0.7,0.6,0.5,0.4,0.3]:
    #     if (np.count_nonzero(chr)/len(chr))<rate:
    #       fitness-=(1.0-rate)
    #       break
    if fitness>best_fit:
      best_fit=fitness
      best_ans=chr.copy()
      out_best_last=margin_score
      out_best_new=score
      count_best=len(chr)-np.count_nonzero(chr)
    # print(fitness,np.log((out_last-out_new)+1.0),((np.count_nonzero(chr)/len(chr))))
    dict_fitnesses[count]=fitness.item()
    count+=1
  # print(len(dict_fitnesses))
  # print('score: ',out_best_new)
  # print(len(best_ans)-np.count_nonzero(best_ans),len(best_ans))
  # print('fitness: ',best_fit)
  # print('----------')
  return dict_fitnesses,best_fit,best_ans,out_best_new,count_best

# %%
def cross_over(th1,th2,new_pop1):
  new_pop2=[]
  # print(len(new_pop1))
  # print()
  for i in range(0,len(new_pop1)-1,2):
    chr1=new_pop1[i]
    chr2=new_pop1[i+1]
    rand_num=np.random.rand()
    if rand_num>0.01:
      new_chr1=list(chr1[0:th1])
      new_chr1+=list(chr2[th1:th2])
      new_chr1+=list(chr1[th2:])

      new_chr2=list(chr2[0:th1])
      new_chr2+=list(chr1[th1:th2])
      new_chr2+=list(chr2[th2:])

      new_pop2.append(new_chr1)
      new_pop2.append(new_chr2)
    else:
      new_pop2.append(chr1)
      new_pop2.append(chr2)
  return new_pop2

# %%
def mutate(new_pop):
  new_pop1=new_pop.copy()
  # print(len(new_pop1))
  # print(len(new_pop))
  rand_count=np.random.randint(0,0.5*int(len(new_pop1)))
  for i in range(rand_count):
    rand_ind=np.random.randint(0,len(new_pop1))
    chr1=new_pop1[rand_ind]
    rand_count2=np.random.randint(0,0.1*int(len(new_pop1)))
    for j in range(rand_count2):
      rand_ind=np.random.randint(0,len(chr1))
      chr1[rand_ind]=1.0-chr1[rand_ind]
  return new_pop1

# %%
num_population=400

# %%
def evaluate_model_perspective(
        rec_dict,
        u_i_exp_dict,
        base_model,
        user_feature_matrix,
        item_feature_matrix,
        rec_k,
        device):
    """
    compute PN, PS and F_NS score for the explanations
    :param rec_dict: {u1: [i1, i2, i3, ...] , u2: [i1, i2, i3, ...]}
    :param u_i_exp_dict: {(u, i): [f1, f2, ...], ...}
    :param base_model: the trained base recommendation model
    :param user_feature_matrix: |u| x |p| matrix, the attention on each feature p for each user u
    :param item_feature_matrix: |i| x |p| matrix, the quality on each feature p for each item i
    :param rec_k: the length of the recommendation list, only generated explanations for the items on the list
    :param device: the device of the model
    :return: the mean of the PN, PS and FNS scores
    """
    pn_count = 0
    ps_count = 0
    dict_items_cf_feature={}
    for u_i, fs in u_i_exp_dict.items():
        user = u_i[0]
        target_item = u_i[1]
        features = set(fs)
        items = rec_dict[user]
        target_index = items.index(target_item)
        # print(len(items))
        # print(features)
        # compute PN
        cf_items_features1 = []
        cf_items_features2 = []
        for item in items:
            # print(item)
            # item_ori_feature = np.array(item_feature_matrix[item])
            item_id=rec_dataset.inv_item_name_dict[item]
            all_features,th1,th2=get_features(item_id)
            # print(all_features)
            item_feature_name=rec_dataset.item_features[item]
            weights1=[0.0 if fea in features else 1.0 for fea in all_features]
            weights2=[1.0 if fea in features else 0.0 for fea in all_features]
            # weights=torch.FloatTensor(weights).to(device)
            if item in dict_items_cf_feature.keys():
              tensor_vect_desc,tensor_vect_title,tensor_vect_feature=dict_items_cf_feature[item]
            else:
              tensor_vect_desc,tensor_vect_title,tensor_vect_feature=get_tensor_vects(item_id)
              dict_items_cf_feature[item]=(tensor_vect_desc,tensor_vect_title,tensor_vect_feature)
            
            item_cf_feature1=get_new_item_vector(item_id,th1,th2,weights1,tensor_vect_desc,tensor_vect_feature,tensor_vect_title).detach().to('cpu').numpy()
            item_cf_feature2=get_new_item_vector(item_id,th1,th2,weights2,tensor_vect_desc,tensor_vect_feature,tensor_vect_title).detach().to('cpu').numpy()
            cf_items_features1.append(item_cf_feature1)
            cf_items_features2.append(item_cf_feature2)
            # print(item_cf_feature)
            # print(torch.from_numpy(np.array(cf_items_features,dtype='float32')).to(device))
            # print(np.shape(item_cf_feature))
            # print(np.shape(cf_items_features))
        # print(np.shape(cf_items_features))
        cf_ranking_scores1 = base_model(torch.from_numpy(np.array([user_feature_matrix[user]
                                                                      for i in range(len(cf_items_features1))])
                                                            ).to(device),
                                           torch.from_numpy(np.array(cf_items_features1,dtype='float32')).to(device)).squeeze()
        cf_score_list1 = cf_ranking_scores1.to('cpu').detach().numpy()
        sorted_index1 = np.argsort(cf_score_list1)[::-1]
        cf_rank1 = np.argwhere(sorted_index1 == target_index)[0, 0]  # the updated ranking of the current item
        if cf_rank1 > rec_k - 1:
            pn_count += 1
        # compute NS
        cf_ranking_scores2 = base_model(torch.from_numpy(np.array([user_feature_matrix[user]
                                                                      for i in range(len(cf_items_features2))])
                                                            ).to(device),
                                           torch.from_numpy(np.array(cf_items_features2,dtype='float32')).to(device)).squeeze()
        cf_score_list2 = cf_ranking_scores2.to('cpu').detach().numpy()
        sorted_index2 = np.argsort(cf_score_list2)[::-1]
        cf_rank2 = np.argwhere(sorted_index2 == target_index)[0, 0]  # the updated ranking of the current item
        if cf_rank2 < rec_k:
            ps_count += 1
    if len(u_i_exp_dict) != 0:
        pn = pn_count / len(u_i_exp_dict)
        ps = ps_count / len(u_i_exp_dict)
        if (pn + ps) != 0:
            fns = (2 * pn * ps) / (pn + ps)
        else:
            fns = 0
    else:
        pn = 0
        ps = 0
        fns = 0
    return pn, ps, fns

# %%
def evaluate_user_perspective(user_perspective_data, u_i_expl_dict):
    pres = []
    recs = []
    f1s = []
    for u_i, gt_features in user_perspective_data.items():
        if u_i in u_i_expl_dict:
            TP = 0
            pre_features = u_i_expl_dict[u_i]
            # print('f: ', gt_features, pre_features)
            for feature in pre_features:
                if feature in gt_features:
                    TP += 1
            # print(gt_features)
            # print(pre_features)
            pre = TP / len(pre_features)
            rec = TP / len(gt_features)
            if (pre + rec) != 0:
                f1 = (2 * pre * rec) / (pre + rec)
            else:
                f1 = 0
            pres.append(pre)
            recs.append(rec)
            f1s.append(f1)
    ave_pre = np.mean(pres)
    ave_rec = np.mean(recs)
    ave_f1 = np.mean(f1s)
    return ave_pre, ave_rec, ave_f1

# %%
class ExpOptimizationModel(torch.nn.Module):
    def __init__(self, base_model, rec_dataset, device):
        super(ExpOptimizationModel, self).__init__()
        self.base_model = base_model
        self.rec_dataset = rec_dataset
        self.device = device
        self.u_i_exp_dict = {}  # {(user, item): [f1, f2, f3 ...], ...}
        self.user_feature_matrix = torch.from_numpy(self.rec_dataset.user_feature_matrix).to(self.device)
        self.item_feature_matrix = torch.from_numpy(self.rec_dataset.item_feature_matrix).to(self.device)
        self.rec_dict, self.user_perspective_test_data = self.generate_rec_dict()

    def generate_rec_dict(self):
        rec_dict = {}
        correct_rec_dict = {}  # used for user-side evaluation
        for row in self.rec_dataset.test_data:
            user = row[0]
            items = row[1]
            labels = row[2]
            correct_rec_dict[user] = []
            user_features = self.user_feature_matrix[user].repeat(len(items), 1)
            scores = self.base_model(user_features,
                        self.item_feature_matrix[items]).squeeze()
            scores = np.array(scores.to('cpu'))
            sort_index = sorted(range(len(scores)), key=lambda k: scores[k], reverse=True)
            sorted_items = [items[i] for i in sort_index]
            rec_dict[user] = sorted_items
            for i in range(rec_k):  # find the correct items and add to the user side test data
                if labels[sort_index[i]] == 1:
                    correct_rec_dict[user].append(items[sort_index[i]])

        user_perspective_test_data = {}  # {(u, i):f, (u, i): f]}
        # for user, items in correct_rec_dict.items():
        #     for item in items:
        #         user_id=rec_dataset.inv_user_name_dict[user]
        #         item_id=rec_dataset.inv_item_name_dict[item]
        #         feature = user_test_perspective[(user_id, item_id)]
        #         user_perspective_test_data[(user, item)] = feature
        return rec_dict, user_perspective_test_data
    def user_side_evaluation(self):
        ave_pre, ave_rec, ave_f1 = evaluate_user_perspective(self.user_perspective_test_data, self.u_i_exp_dict)
        print('user\'s perspective:')
        print('ave pre: ', ave_pre, '  ave rec: ', ave_rec, '  ave f1: ', ave_f1)
    
    def model_side_evaluation(self):
        ave_pn, ave_ps, ave_fns = evaluate_model_perspective(
            self.rec_dict,
            self.u_i_exp_dict,
            self.base_model,
            self.rec_dataset.user_feature_matrix,
            self.rec_dataset.item_feature_matrix,
            rec_k,
            self.device)
        print('model\'s perspective:')
        print('ave PN: ', ave_pn, '  ave PS: ', ave_ps, '  ave F_{NS}: ', ave_fns)  
    def generate_explanation(self):
        # u_i_exps_dict = {}  # {(user, item): [f1, f2, f3 ...], ...}
        exp_nums = []
        exp_complexities = []
        self.no_exp_count = 0
        if test_num == -1:
            test_num1 = len(list(self.rec_dict.items()))
        else:
            test_num1 = test_num
        count=0
        for user, items in tqdm.tqdm(list(self.rec_dict.items())[:10]):
            user_id=self.rec_dataset.inv_user_name_dict[user]
            count+=1
            # if count<200:
            #   continue
            # if count==3:
            #   break
            items = self.rec_dict[user]
            margin_item = items[rec_k]
            margin_score = self.base_model(self.user_feature_matrix[user].unsqueeze(0), 
                            self.item_feature_matrix[margin_item].unsqueeze(0)).squeeze()
            # print('margin_score: ',margin_score)
            for item in items[: rec_k]:
                item_id=self.rec_dataset.inv_item_name_dict[item]
                tensor_vect_desc,tensor_vect_title,tensor_vect_feature=get_tensor_vects(item_id)
                explanation_features_words, exp_num=self.get_explanation(item_id,margin_score,user_id,tensor_vect_desc,tensor_vect_title,tensor_vect_feature)
                
                if explanation_features_words is None:
                    # print('no explanation for user %d and item %d' % (user, item))
                    self.no_exp_count += 1
                else:
                    self.u_i_exp_dict[(user, item)] = explanation_features_words
                    # print(explanation_features_words)
                    exp_nums.append(exp_num)

              
        print('ave num: ', np.mean(exp_nums), 'ave complexity: ', np.mean(exp_complexities) , 'no_exp_count: ', self.no_exp_count)
        return True
    def get_explanation(self,item_id,margin_score,user_id,tensor_vect_desc,tensor_vect_title,tensor_vect_feature):
      best_answer=[]
      best_fit_all=-10000.0
      features,th1,th2=get_features(item_id)
      # print(features)
      population=get_first_population(num_population,features)
      # print(len(population))
      # print(population)
      exit=False
      iter=0
      while not exit:
        fitnesses,best_fit,best_ans,best_score,count_zero= calc_fitnesses(margin_score,population,th1,th2,user_id,item_id,self.base_model,tensor_vect_desc,tensor_vect_title,tensor_vect_feature)
        # print(population[0])
        # print(fitnesses)
        # if iter%1==0:
        #   print('iter: ', iter, 'best_fit: ',best_fit , 'best_score: ', best_score , 'count_fea: ', count_zero )
        iter+=1
        if best_fit>best_fit_all:
          best_fit_all=best_fit
          best_answer=best_ans.copy()
        dict_probs={}
        for key in fitnesses.keys():
          # print(fitnesses[key])
          # print(np.sum(list(fitnesses.values())))
          dict_probs[key]=fitnesses[key]/np.sum(list(fitnesses.values()))
        dict_chooses={}
        last_prob=0
        sum_prob=0
        for key in dict_probs.keys():
          prob=dict_probs[key]
          dict_chooses[(sum_prob,prob+sum_prob)]=key
          sum_prob+=prob
        # print(dict_chooses)
        new_pop1=select_chrs(dict_chooses,num_population,population)
        # print(len(new_pop1))
        new_pop2=cross_over(th1,th2,new_pop1)
        # print(len(new_pop2))
        rand_num=np.random.rand()
        if rand_num>0.9:
          new_pop3=mutate(new_pop2)
          # print(len(new_pop3))
        else:
          new_pop3=new_pop2.copy()
        population=new_pop3.copy()
        if best_fit_all.cpu()>=1.0 and iter==10:
          exit=True 
        elif iter==50:
          exit=True
      if best_fit_all.cpu()>=1.0:
        best_features=[features[i] for i in range(len(features)) if best_answer[i]<1]
        # print(best_features)
        return best_features,len(best_features)
      else:
        # print('no explanation')
        return None,None

# %%
def get_tensor_vect_df(df,not_in_columns):
  df1=df.copy()
  df1['main_word']=np.where(df1['replaced_word'] == df1[not_in_columns],1,0)
  df1=df1[df1['main_word']==1]
  if df1.empty:
    df1=df.copy()
    df1['main_word']=np.where(df1['logit']==5.0,1,0)
    df1=df1[df1['main_word']==1]
  if df1.empty:
    df1=df.copy()
    df1['main_word']=np.where(df1['logit']==12.0,1,0)
    df1=df1[df1['main_word']==1]
  lists=df1.loc[:, ~df1.columns.isin([not_in_columns,'replaced_word','logit','main_word'])].values
  words=df1[not_in_columns].values
  # print(words)
  vects=[sub_list[0] for sub_list in lists]
  tensor_vect=torch.FloatTensor(vects).to(device)
  return tensor_vect

# %%
def get_tensor_vects(item_id):
  tensor_vect_desc=None
  tensor_vect_title=None
  tensor_vect_feature=None
  if os.path.exists(save_path+'description_bert/'+'df_bert_desc_{}.json'.format(item_id)) :
      df_vect_desc= pd.read_json(save_path+'description_bert/'+'df_bert_desc_{}.json'.format(item_id))
      tensor_vect_desc=get_tensor_vect_df(df_vect_desc,'description_words')

      df_vect_title= pd.read_json(save_path+'title_bert/'+'df_bert_title_{}.json'.format(item_id))
      tensor_vect_title=get_tensor_vect_df(df_vect_title,'title_words')

      df_vect_feature= pd.read_json(save_path+'feature_bert/'+'df_bert_feature_{}.json'.format(item_id))
      tensor_vect_feature=get_tensor_vect_df(df_vect_feature,'feature_words')
  return tensor_vect_desc,tensor_vect_title,tensor_vect_feature

# %%
def generate_explanation():
    if gpu:
        device = torch.device('cuda:%s' %cuda)
    else:
        device = 'cpu'
    print(device)
    # import dataset
    with open(os.path.join(data_obj_path, dataset + "_dataset_obj.pickle"), 'rb') as inp:
        rec_dataset = pickle.load(inp)
    base_model = BaseRecModel(rec_dataset.feature_num).to(device)
    base_model.load_state_dict(torch.load(os.path.join(base_model_path,"model.model"),map_location=torch.device(device)))
    base_model.eval()
    #  fix the rec model
    for param in base_model.parameters():
        param.requires_grad = False
    
    # Create optimization model
    opt_model = ExpOptimizationModel(
        base_model=base_model,
        rec_dataset=rec_dataset,
        device = device,
        
    )

    opt_model.generate_explanation()
    Path(save_path).mkdir(parents=True, exist_ok=True)
    with open(os.path.join(save_path, dataset + "_explanation_obj_genetic.pickle"), 'wb') as outp:
        pickle.dump(opt_model, outp, pickle.HIGHEST_PROTOCOL)
    # with open(os.path.join(save_path, dataset + "_explanation_obj.pickle"), 'rb') as opt:
    #     opt_model = pickle.load(opt)
    opt_model.user_side_evaluation()
    opt_model.model_side_evaluation()
    # print(opt_model.u_i_exp_dict)
    # Path(save_path).mkdir(parents=True, exist_ok=True)
    # with open(os.path.join(save_path, dataset + "_explanation_obj.pickle"), 'wb') as outp:
    #     pickle.dump(opt_model, outp, pickle.HIGHEST_PROTOCOL)
    return opt_model


if __name__ == "__main__":
    opt_model=generate_explanation()
# Out:
# cuda:0
# 100%|██████████| 93/93 [57:59<00:00, 37.41s/it]
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ave num:  17.591792656587472 ave complexity:  nan no_exp_count:  2
# user's perspective:
# ave pre:  0.10192027014937338   ave rec:  0.11002879872879187   ave f1:  0.08371325402060242
# model's perspective:
# ave PN:  0.8466522678185745   ave PS:  0.9848812095032398   ave F_{NS}:  0.9105505521822405

# %% [markdown]
# # Calculate Stability...

# %%
def generate_explanation_check_stability():
    if gpu:
        device = torch.device('cuda:%s' %cuda)
    else:
        device = 'cpu'
    print(device)
    with open(os.path.join(data_obj_path, dataset + "_dataset_obj.pickle"), 'rb') as inp:
        rec_dataset = pickle.load(inp)
    base_model = BaseRecModel(rec_dataset.feature_num).to(device)
    base_model.load_state_dict(torch.load(os.path.join(base_model_path,"model.model"),map_location=torch.device(device)))
    base_model.eval()
    #  fix the rec model
    for param in base_model.parameters():
        param.requires_grad = False
    
    
    # Create optimization model

    features_found=[]
    for i in range(10):
      opt_model = ExpOptimizationModel(
        base_model=base_model,
        rec_dataset=rec_dataset,
        device = device,)
      opt_model.generate_explanation()
      features_found.append(opt_model.u_i_exp_dict)
    return features_found

if __name__ == "__main__":
    features_found=generate_explanation_check_stability()
# Out:
# cuda:0
# 100%|██████████| 10/10 [04:13<00:00, 25.35s/it]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ave num:  14.795918367346939 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:23<00:00, 20.32s/it]
# ave num:  17.16 ave complexity:  nan no_exp_count:  0
# 100%|██████████| 10/10 [03:46<00:00, 22.64s/it]
# ave num:  14.755102040816327 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:21<00:00, 20.16s/it]
# ave num:  14.448979591836734 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:12<00:00, 19.25s/it]
# ave num:  14.448979591836734 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:23<00:00, 20.40s/it]
# ave num:  14.346938775510203 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:35<00:00, 21.50s/it]
# ave num:  16.04 ave complexity:  nan no_exp_count:  0
# 100%|██████████| 10/10 [03:23<00:00, 20.36s/it]
# ave num:  14.16326530612245 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:09<00:00, 18.99s/it]
# ave num:  13.857142857142858 ave complexity:  nan no_exp_count:  1
# 100%|██████████| 10/10 [03:43<00:00, 22.40s/it]
# ave num:  16.428571428571427 ave complexity:  nan no_exp_count:  1

# %%
dict_features={}
for iter_feas in features_found:
  for u_i in iter_feas.keys():
    # feas=list(iter_feas[u_i][0][0].columns)
    feas=iter_feas[u_i]
    # print(iter_feas[u_i])
    if u_i in dict_features.keys():
      dict_features[u_i].append(feas)
    else:
      dict_features[u_i]=[]
      dict_features[u_i].append(feas)

# %%
dict_features
# Out:
# {(6,
#   1810): [['candyshell',
#    'interior',
#    'rubberized',
#    'please',
#    'rep',
#    'approval',
#    'samsung',
#    'galaxy',
#    'edge',
#    'case',
#    'galaxy',
#    'speck',
#    'candyshell',
#    'military',
#    'dual',
#    'interior',
#    'high',
#    'polycarbonate'], ['provides',
#    'layer',
#    'products',
#    'samsung',
#    'galaxy',
#    'edge',
#    'galaxy',
#    'candyshell',
#    'samsung',
#    'std',
#    'impact'], ['provides',
#    'covers',
#    'account',
#    'rep',
#    'galaxy',
#    'edge',
#    'military',
#    'protective',
#    'galaxy',
#    'edge',
#    'mil',
#    'layer',
#    'time'], ['provides',
#    'outer',
#    'raised',
#    'add',
#    'bezel',
#    'samsung',
#    'galaxy',
#    'edge',
#    'protective',
#    'case',
#    'edge',
#    'speck',
#    'fits',
#    'military',
#    'durable',
#    'polycarbonate'], ['rep',
#    'approval',
#    'products',
#    'samsung',
#    'galaxy',
#    'edge',
#    'case',
#    'protective',
#    'galaxy',
#    'edge',
#    'shock',
#    'stays',
#    'completely',
#    'clarity',
#    'durable',
#    'abrasions'], ['case',
#    'provides',
#    'candyshell',
#    'hard',
#    'outer',
#    'guards',
#    'covers',
#    'sales',
#    'military',
#    'grade',
#    'galaxy',
#    'speck',
#    'design',
#    'clear',
#    'high',
#    'resistant'], ['samsung',
#    'galaxy',
#    'candyshell',
#    'hard',
#    'protects',
#    'raised',
#    'screen',
#    'extra',
#    'galaxy',
#    'case',
#    'grade',
#    'galaxy',
#    'edge',
#    'galaxy',
#    'shock',
#    'clear',
#    'definition',
#    'materials'], ['protects',
#    'extra',
#    'protection',
#    'products',
#    'galaxy',
#    'edge',
#    'galaxy',
#    'candyshell',
#    'layer',
#    'hardshell',
#    'time',
#    'layers',
#    'achieve'], ['candyshell',
#    'scratches',
#    'layer',
#    'drops',
#    'damage',
#    'covers',
#    'extra',
#    'customers',
#    'account',
#    'rep',
#    'galaxy',
#    'clear',
#    'grade',
#    'galaxy',
#    'protection',
#    'exceeds',
#    'clarity',
#    'scratch',
#    'resistant'], ['galaxy',
#    'provides',
#    'shell',
#    'rubberized',
#    'button',
#    'samsung',
#    'galaxy',
#    'edge',
#    'military',
#    'edge',
#    'fits',
#    'innovative',
#    'finish']],
#  (6,
#   1847): [['car',
#    'installing',
#    'place',
#    'keep',
#    'steps',
#    'launch',
#    'zerotouch',
#    'bluetooth',
#    'preferences',
#    'runs',
#    'mobile',
#    'carrier',
#    'simply',
#    'location',
#    'speak',
#    'simply',
#    'say',
#    'hangouts',
#    'whatsapp',
#    'account',
#    'need',
#    'app',
#    'intended',
#    'zerotouch',
#    'phone',
#    'android',
#    'covers',
#    'mounted',
#    'larger',
#    'use',
#    'logitech',
#    'free',
#    'voice',
#    'assistant',
#    'amazon',
#    'android',
#    'phones',
#    'logitech',
#    'connectivity',
#    'hands',
#    'compatibility',
#    'required',
#    'required',
#    'compatible'], ['phone',
#    'car',
#    'alexa',
#    'screen',
#    'bluetooth',
#    'set',
#    'runs',
#    'next',
#    'calling',
#    'play',
#    'app',
#    'settings',
#    'thousands',
#    'available',
#    'text',
#    'read',
#    'last',
#    'play',
#    'time',
#    'zerotouch',
#    'ios',
#    'case',
#    'textured',
#    'phone',
#    'distributes',
#    'follow',
#    'ideal',
#    'phones',
#    'smooth',
#    'phone',
#    'car',
#    'mount',
#    'alexa',
#    'android',
#    'phones',
#    'zerotouch',
#    'world',
#    'free',
#    'alexa',
#    'high',
#    'skills',
#    'alexa',
#    'compatibility',
#    'account',
#    'pandora',
#    'amazon',
#    'music',
#    'via'], ['required',
#    'use',
#    'zerotouch',
#    'set',
#    'customize',
#    'android',
#    'bluetooth',
#    'wake',
#    'word',
#    'alexa',
#    'timezone',
#    'word',
#    'calling',
#    'etc',
#    'music',
#    'time',
#    'iheartradio',
#    'zerotouch',
#    'cases',
#    'flip',
#    'sensor',
#    'purpose',
#    'metal',
#    'metal',
#    'phone',
#    'provide',
#    'amazon',
#    'exclusively',
#    'android',
#    'phones',
#    'zerotouch',
#    'hands',
#    'high',
#    'five',
#    'normally',
#    'full',
#    'works',
#    'alexa',
#    'free',
#    'android',
#    'wireless',
#    'technology',
#    'amazon',
#    'assistance'], ['mount',
#    'keep',
#    'purchase',
#    'calling',
#    'navigation',
#    'alexa',
#    'store',
#    'follow',
#    'install',
#    'mount',
#    'phone',
#    'customize',
#    'wireless',
#    'text',
#    'messaging',
#    'music',
#    'zerotouch',
#    'wake',
#    'high',
#    'alexa',
#    'alexa',
#    'wake',
#    'facebook',
#    'functionality',
#    'read',
#    'replying',
#    'whatsapp',
#    'account',
#    'spotify',
#    'compatible',
#    'asked',
#    'zerotouch',
#    'zerotouch',
#    'compatible',
#    'requires',
#    'rhinestones',
#    'weight',
#    'mounted',
#    'sview',
#    'purpose',
#    'follow',
#    'app',
#    'smaller',
#    'shaped',
#    'attachment',
#    'phone',
#    'phones',
#    'larger',
#    'product',
#    'alexa',
#    'android',
#    'phones',
#    'calling',
#    'email',
#    'speak',
#    'would',
#    'supports',
#    'alexa',
#    'wake',
#    'five',
#    'skills',
#    'simply',
#    'phone',
#    'mount',
#    'automatically',
#    'app',
#    'data',
#    'running',
#    'later',
#    'google',
#    'alexa',
#    'customer',
#    'assistance',
#    'questions'], ['hands',
#    'free',
#    'connectivity',
#    'store',
#    'attach',
#    'adapter',
#    'bluetooth',
#    'simply',
#    'apply',
#    'calling',
#    'simply',
#    'jazz',
#    'alexa',
#    'texts',
#    'replying',
#    'whatsapp',
#    'active',
#    'use',
#    'ios',
#    'zerotouch',
#    'hold',
#    'thicker',
#    'secures',
#    'attachment',
#    'charging',
#    'larger',
#    'smooth',
#    'phone',
#    'logitech',
#    'assistant',
#    'amazon',
#    'android',
#    'phones',
#    'connectivity',
#    'hands',
#    'free',
#    'text',
#    'calendar',
#    'music',
#    'music',
#    'alexa',
#    'interface',
#    'control',
#    'high',
#    'mount',
#    'free',
#    'compatibility',
#    'mobile',
#    'running',
#    'android',
#    'technology',
#    'account',
#    'google',
#    'assistance'], ['wheel',
#    'attach',
#    'mount',
#    'later',
#    'bluetooth',
#    'data',
#    'message',
#    'functionality',
#    'thousands',
#    'messages',
#    'google',
#    'services',
#    'available',
#    'high',
#    'text',
#    'amy',
#    'mom',
#    'full',
#    'use',
#    'zerotouch',
#    'zerotouch',
#    'covers',
#    'weight',
#    'mounted',
#    'metal',
#    'smaller',
#    'pill',
#    'adapter',
#    'logitech',
#    'amazon',
#    'android',
#    'phones',
#    'zerotouch',
#    'alexa',
#    'music',
#    'via',
#    'alexa',
#    'word',
#    'alexa',
#    'skills',
#    'place',
#    'phone',
#    'launch',
#    'full',
#    'music',
#    'spotify',
#    'support',
#    'assistance'], ['use',
#    'app',
#    'follow',
#    'pair',
#    'preferences',
#    'waiting',
#    'zerotouch',
#    'message',
#    'charges',
#    'amazon',
#    'alexa',
#    'control',
#    'five',
#    'example',
#    'alexa',
#    'read',
#    'ldquo',
#    'rdquo',
#    'soundcloud',
#    'requires',
#    'etc',
#    'otterbox',
#    'flip',
#    'cover',
#    'weight',
#    'app',
#    'adapter',
#    'attachment',
#    'wireless',
#    'adapter',
#    'provide',
#    'hands',
#    'car',
#    'voice',
#    'app',
#    'amazon',
#    'android',
#    'phones',
#    'black',
#    'world',
#    'alexa',
#    'functionality',
#    'via',
#    'five',
#    'hands',
#    'active',
#    'soundcloud',
#    'customer',
#    'technical'], ['car',
#    'solution',
#    'road',
#    'setting',
#    'messaging',
#    'amazon',
#    'high',
#    'set',
#    'high',
#    'read',
#    'last',
#    'whatsapp',
#    'services',
#    'requires',
#    'work',
#    'ios',
#    'zerotouch',
#    'devices',
#    'one',
#    'direct',
#    'voice',
#    'app',
#    'amazon',
#    'exclusively',
#    'android',
#    'phones',
#    'zerotouch',
#    'car',
#    'world',
#    'high',
#    'alexa',
#    'alexa',
#    'music',
#    'voice',
#    'mount',
#    'automatically',
#    'compatibility',
#    'android',
#    'music',
#    'functionality',
#    'account',
#    'music',
#    'compatible',
#    'technical',
#    'iheartradio'], ['hands',
#    'car',
#    'hands',
#    'music',
#    'install',
#    'mount',
#    'phone',
#    'requirements',
#    'active',
#    'alexa',
#    'alexa',
#    'high',
#    'five',
#    'measurement',
#    'high',
#    'news',
#    'simply',
#    'amy',
#    'mom',
#    'play',
#    'ldquo',
#    'music',
#    'work',
#    'compatible',
#    'android',
#    'zerotouch',
#    'covers',
#    'samsung',
#    'larger',
#    'adapter',
#    'free',
#    'assistant',
#    'amazon',
#    'alexa',
#    'android',
#    'phones',
#    'phone',
#    'would',
#    'alexa',
#    'wake',
#    'high',
#    'five',
#    'automatically',
#    'app',
#    'running',
#    'later',
#    'required'], ['hands',
#    'car',
#    'magnetic',
#    'mount',
#    'speak',
#    'purchase',
#    'app',
#    'follow',
#    'car',
#    'adapter',
#    'bluetooth',
#    'place',
#    'phone',
#    'driving',
#    'customize',
#    'bluetooth',
#    'active',
#    'except',
#    'alexa',
#    'messaging',
#    'full',
#    'music',
#    'zerotouch',
#    'music',
#    'works',
#    'high',
#    'download',
#    'settings',
#    'alexa',
#    'thousands',
#    'skills',
#    'alexa',
#    'alexa',
#    'texts',
#    'facebook',
#    'five',
#    'mom',
#    'play',
#    'spotify',
#    'full',
#    'pandora',
#    'google',
#    'play',
#    'spotify',
#    'radio',
#    'time',
#    'frequently',
#    'app',
#    'work',
#    'currently',
#    'ios',
#    'flip',
#    'cover',
#    'blocks',
#    'placement',
#    'adapter',
#    'metal',
#    'ideal',
#    'phone',
#    'logitech',
#    'amazon',
#    'android',
#    'world',
#    'hands',
#    'navigation',
#    'email',
#    'calendar',
#    'alexa',
#    'activate',
#    'normally',
#    'alexa',
#    'messaging',
#    'full',
#    'functionality',
#    'works',
#    'via',
#    'voice',
#    'high',
#    'say',
#    'car',
#    'launch',
#    'hands',
#    'app',
#    'data',
#    'required',
#    'smartphones',
#    'android',
#    'services',
#    'music',
#    'spotify',
#    'via',
#    'compatible',
#    'support',
#    'support']],
#  (6,
#   1174): [['vent',
#    'okra',
#    'quality',
#    'smooth',
#    'minimizes',
#    'warranty',
#    'product',
#    'product',
#    'phone',
#    'iphone',
#    'gripping',
#    'interaction',
#    'gesturing',
#    'ibd',
#    'apply',
#    'save'], ['rectangular',
#    'using',
#    'car',
#    'includes',
#    'rubber',
#    'lifetime',
#    'purchase',
#    'iphone',
#    'android',
#    'smartphones',
#    'qualified',
#    'ibd'], ['simplicity',
#    'one',
#    'back',
#    'car',
#    'vibrations',
#    'interaction',
#    'maximizes',
#    'adhesive',
#    'phone',
#    'iphone',
#    'okra',
#    'circle',
#    'plates',
#    'compatible'], ['plus',
#    'place',
#    'vent',
#    'okra',
#    'strong',
#    'device',
#    'adhesive',
#    'okra',
#    'products',
#    'register',
#    'product',
#    'phone',
#    'iphone',
#    'plates',
#    'mount',
#    'apply',
#    'enter'], ['place',
#    'rectangular',
#    'plates',
#    'inside',
#    'one',
#    'using',
#    'fix',
#    'assists',
#    'circle',
#    'purchase',
#    'worry',
#    'phone',
#    'iphone',
#    'universal',
#    'code',
#    'save'], ['mounting',
#    'vent',
#    'adhesive',
#    'okra',
#    'cradle',
#    'less',
#    'work',
#    'okra',
#    'phone',
#    'iphone',
#    'vibrations',
#    'interaction',
#    'checkout',
#    'apply'], ['plates',
#    'angle',
#    'best',
#    'distracting',
#    'tapping',
#    'adhesive',
#    'included',
#    'lifetime',
#    'register',
#    'phone',
#    'iphone',
#    'universal',
#    'smartphone',
#    'cellphone',
#    'quality',
#    'ibd',
#    'qualified'], ['simply',
#    'two',
#    'secure',
#    'fix',
#    'distracting',
#    'gripping',
#    'mount',
#    'rectangle',
#    'simply',
#    'purchase',
#    'phone',
#    'android',
#    'devices',
#    'smartphones',
#    'rubber',
#    'smooth',
#    'slippage',
#    'ibd'], ['magnetic',
#    'htc',
#    'one',
#    'using',
#    'arms',
#    'universal',
#    'rectangle',
#    'enjoy',
#    'phone',
#    'iphone',
#    'android',
#    'gps',
#    'gripping',
#    'code',
#    'checkout',
#    'offered'], ['magnetic',
#    'car',
#    'best',
#    'circle',
#    'plates',
#    'smartphone',
#    'compatible',
#    'minimizes',
#    'products',
#    'every',
#    'okra',
#    'warranty',
#    'iphone',
#    'android',
#    'devices',
#    'cellphone',
#    'gesturing',
#    'maximizes']],
#  (6, 1809): [['screen', 'galaxy', 'construction', 'tested'],
#   ['candyshell', 'outer', 'galaxy', 'guards', 'raised'],
#   ['protection', 'add', 'bezel', 'rubberized', 'galaxy'],
#   ['galaxy', 'case', 'retaining', 'full', 'impact'],
#   ['damage', 'galaxy', 'revolution', 'functionality', 'unrelenting'],
#   ['galaxy', 'candyshell', 'galaxy', 'ease'],
#   ['interior', 'galaxy', 'candyshell'],
#   ['galaxy', 'shell', 'galaxy', 'military'],
#   ['samsung', 'drops', 'galaxy', 'piece'],
#   ['galaxy', 'speck', 'patented', 'phone', 'helps', 'corners']],
#  (6, 1311): [['purple', 'website'],
#   ['galaxy', 'purple', 'block'],
#   ['ready', 'galaxy', 'details'],
#   ['force', 'purple', 'profile'],
#   ['divert', 'purple', 'compatible'],
#   ['purple', 'liberty', 'port'],
#   ['purple'],
#   ['protects', 'purple', 'protection'],
#   ['sleek', 'purple', 'piece'],
#   ['protects', 'purple', 'otterbox']],
#  (8,
#   911): [['molded',
#    'construction',
#    'advantage',
#    'saving',
#    'retractable',
#    'data',
#    'speed',
#    'usb',
#    'usb',
#    'provides',
#    'appointments',
#    'take',
#    'advantage',
#    'room'], ['transfer',
#    'features',
#    'provides',
#    'take',
#    'useful',
#    'saving',
#    'carrying',
#    'durability',
#    'micro',
#    'phone',
#    'emails',
#    'saving',
#    'room',
#    'easily',
#    'durability'], ['high',
#    'male',
#    'micro',
#    'provides',
#    'connect',
#    'pictures',
#    'advantage',
#    'carrying',
#    'synchronize',
#    'speed',
#    'male',
#    'universal',
#    'micro',
#    'provides',
#    'tones',
#    'saving',
#    'adapter'], ['micro',
#    'ring',
#    'adapter',
#    'retractable',
#    'data',
#    'usb',
#    'access',
#    'phone',
#    'appointments',
#    'change',
#    'pictures',
#    'advantage',
#    'saving',
#    'carrying',
#    'synchronize'], ['connectors',
#    'male',
#    'phone',
#    'appointments',
#    'change',
#    'adapter',
#    'usb',
#    'connectors',
#    'usb',
#    'features',
#    'provides',
#    'easily',
#    'carrying',
#    'adapter'], ['take',
#    'data',
#    'motorola',
#    'micro',
#    'male',
#    'book',
#    'emails',
#    'tones',
#    'pictures',
#    'easily',
#    'carrying',
#    'adapter',
#    'retractable'], ['transfer',
#    'provides',
#    'phone',
#    'ring',
#    'advantage',
#    'useful',
#    'room',
#    'adapter',
#    'data',
#    'provides',
#    'saving',
#    'carrying'], ['black',
#    'provides',
#    'emails',
#    'adapter',
#    'data',
#    'usb',
#    'micro',
#    'provides',
#    'ring',
#    'take',
#    'advantage',
#    'applications',
#    'saving',
#    'synchronize'], ['high',
#    'male',
#    'usb',
#    'micro',
#    'ring',
#    'saving',
#    'blackberry',
#    'motorola',
#    'usb',
#    'usb',
#    'connectors',
#    'features',
#    'provides',
#    'access',
#    'phone',
#    'saving'], ['male',
#    'features',
#    'construction',
#    'provides',
#    'appointments',
#    'advantage',
#    'useful',
#    'usb',
#    'male',
#    'black',
#    'micro',
#    'features',
#    'provides',
#    'change',
#    'background',
#    'room']],
#  (8,
#   951): [['powerful',
#    'designed',
#    'popular',
#    'sound',
#    'aides',
#    'universal',
#    'jack',
#    'support',
#    'input',
#    '5mm',
#    'conversations',
#    'smartphones',
#    'button',
#    'pause',
#    'hang',
#    'phone',
#    'year',
#    'worry',
#    'please',
#    'service',
#    'pair',
#    'volume',
#    'microphone',
#    'free',
#    'vloume',
#    'works',
#    'ios',
#    'system',
#    'acoustic',
#    'distortion',
#    'bring',
#    'tonesthe',
#    'treble',
#    'authentic',
#    'clear',
#    'sound',
#    'isolation',
#    'optimized',
#    'year',
#    'contact',
#    'ear'], ['deliver',
#    'deep',
#    'perfectly',
#    'magnets',
#    'powerful',
#    'response',
#    'remote',
#    'conversations',
#    'smartphones',
#    'button',
#    'song',
#    'worry',
#    'asap',
#    'covered',
#    'headphones',
#    'warranty',
#    'free',
#    'built',
#    'mic',
#    'ear',
#    'bud',
#    'system',
#    'android',
#    'systemthe',
#    'headphone',
#    'delivers',
#    'clean',
#    'distortion',
#    'bass',
#    'bring',
#    'tonesthe',
#    'sleek',
#    'compact',
#    'authentic',
#    'isolation',
#    'optimized',
#    'phone'], ['sound',
#    'high',
#    'deliver',
#    'music',
#    'neodymium',
#    'allows',
#    'high',
#    'level',
#    'reproduction',
#    'powerful',
#    'jack',
#    'compatible',
#    'port',
#    'mic',
#    'easy',
#    'call',
#    'control',
#    'one',
#    'phone',
#    'service',
#    'team',
#    'bought',
#    '5mm',
#    'free',
#    'design',
#    'system',
#    'android',
#    'systemthe',
#    'acoustic',
#    'delivers',
#    'sleek',
#    'perfect',
#    'lover',
#    'year',
#    'feel',
#    'contact',
#    'phone'], ['sound',
#    'music',
#    'high',
#    'sound',
#    'compatibility',
#    'input',
#    'line',
#    'device',
#    'play',
#    'previous',
#    'one',
#    'satisfied',
#    'asap',
#    'every',
#    'pair',
#    'microphone',
#    'android',
#    'etre',
#    'jeune',
#    '5mm',
#    'mic',
#    'ear',
#    'phone',
#    'earbud',
#    'richer',
#    'innovative',
#    'distortion',
#    'bass',
#    'feature',
#    'isolation',
#    'optimized',
#    'feel',
#    'contact',
#    'questions'], ['powerful',
#    'popular',
#    'music',
#    'genres',
#    'neodymium',
#    'reproduction',
#    'devices',
#    '5mm',
#    'hang',
#    'next',
#    'year',
#    'warranty',
#    'volume',
#    'etre',
#    'jeune',
#    'built',
#    'control',
#    'android',
#    'android',
#    'system',
#    'acoustic',
#    'bass',
#    'bring',
#    'feature',
#    'noise',
#    'optimized',
#    'one',
#    'feel',
#    'free',
#    'phone'], ['premium',
#    'high',
#    'support',
#    'video',
#    'call',
#    'play',
#    'tracker',
#    'song',
#    'year',
#    'worry',
#    'feel',
#    'free',
#    'headphones',
#    'pair',
#    'jeune',
#    'free',
#    'design',
#    'ear',
#    'convenient',
#    'use',
#    'works',
#    'design',
#    'delivers',
#    'response',
#    'feature',
#    'noise',
#    'lightweightthe',
#    'year',
#    'questions'], ['specially',
#    'powerful',
#    'music',
#    'genres',
#    'magnets',
#    'design',
#    'allows',
#    'powerful',
#    'extended',
#    'aides',
#    'universal',
#    'port',
#    'line',
#    'remote',
#    'easy',
#    'conversations',
#    'whether',
#    'play',
#    'pause',
#    'phone',
#    'tracker',
#    'previous',
#    'one',
#    'please',
#    'feel',
#    'contact',
#    'warranty',
#    'team',
#    'bought',
#    'covered',
#    'year',
#    'ofspower',
#    'microphone',
#    'free',
#    'mic',
#    'line',
#    'remote',
#    'android',
#    'like',
#    'richer',
#    'acoustic',
#    'perfect',
#    'tonesthe',
#    'treble',
#    'feature',
#    'authentic',
#    'contact'], ['powerful',
#    'popular',
#    'genres',
#    'high',
#    'response',
#    'compatibility',
#    'compatible',
#    'devices',
#    'support',
#    'headphone',
#    'built',
#    'allows',
#    'device',
#    'whether',
#    'using',
#    'smartphones',
#    'play',
#    'pause',
#    'music',
#    'tracker',
#    'previous',
#    'please',
#    'feel',
#    'free',
#    'contact',
#    'questions',
#    'service',
#    'team',
#    'headphones',
#    'ofspower',
#    'pair',
#    'android',
#    'vloume',
#    'use',
#    'line',
#    'android',
#    'works',
#    'acoustic',
#    'design',
#    'response',
#    'distortion',
#    'free',
#    'audio',
#    'sound',
#    'isolation',
#    'year'], ['premium',
#    'designed',
#    'drivers',
#    'design',
#    'high',
#    'devices',
#    'port',
#    'microphone',
#    'conversations',
#    'video',
#    'computer',
#    'control',
#    'next',
#    'one',
#    'give',
#    'solution',
#    'bought',
#    'ofspower',
#    'pair',
#    'microphone',
#    'noise',
#    'etre',
#    'design',
#    'vloume',
#    'ear',
#    'android',
#    'richer',
#    'delivers',
#    'response',
#    'tonesthe',
#    'music',
#    'lover',
#    'feature',
#    'isolation',
#    'earphones',
#    'questions',
#    'phone']],
#  (8,
#   1412): [['sport',
#    'enhance',
#    'proven',
#    'apple',
#    'speck',
#    'apple',
#    'surprisingly',
#    'easily',
#    'accelerated'], ['apple',
#    'candy',
#    'drops',
#    'protection',
#    'apple',
#    'white',
#    'soft',
#    'flex',
#    'apple'], ['apple',
#    'sport',
#    'long',
#    'apple',
#    'speck',
#    'absorbing',
#    'slim'], ['watch',
#    'fully',
#    'apple',
#    'speck',
#    'soft',
#    'interior',
#    'guard'], ['watch',
#    'sport',
#    'shock',
#    'bumps',
#    'warranty',
#    'apple',
#    'speck',
#    'watch',
#    'fit',
#    'temperatures'], ['apple',
#    'variety',
#    'shell',
#    'watch',
#    'apple',
#    'design',
#    'edition',
#    '42mm',
#    'design',
#    'life'], ['watch',
#    'surprising',
#    'warranty',
#    'apple',
#    'speck',
#    'perimeter',
#    '42mm',
#    'shock',
#    'easily',
#    'testing'], ['apple',
#    'interior',
#    'watch',
#    'design',
#    'backed',
#    'apple',
#    'speck',
#    'wraps',
#    'fully',
#    'surprisingly',
#    'minimal'], ['apple',
#    'available',
#    'white',
#    '42mm',
#    'fully',
#    'shock',
#    'slim',
#    'abrasions'], ['colors',
#    'lets',
#    'impact',
#    'year',
#    'long',
#    'apple',
#    '42mm',
#    'shell']],
#  (8,
#   448): [['galaxy',
#    'stay',
#    'spare',
#    'mind',
#    'battery',
#    'charger',
#    'inconvenience',
#    'samsung',
#    'bag',
#    'stores',
#    'fits',
#    'purse',
#    'charging',
#    'middot',
#    'size',
#    'makes',
#    'home',
#    'charger',
#    'battery',
#    'usb',
#    'travel',
#    'phone',
#    'corporation',
#    'develops',
#    'communications',
#    'including',
#    'five',
#    'authentic',
#    'product',
#    'receive',
#    'non',
#    'compartment',
#    'charging',
#    'spare',
#    'battery',
#    'samsung',
#    'galaxy',
#    'protective',
#    'spare',
#    'charged',
#    'portability',
#    'briefcase',
#    'includes',
#    'usb',
#    '700mah',
#    'charging',
#    'charging',
#    'galaxy',
#    'electronics',
#    'communications',
#    'mobile',
#    'phone',
#    'loyalty',
#    'manufacturer',
#    'worldwide',
#    'samsung',
#    'included',
#    'dead',
#    '2600mah',
#    'seconds',
#    'low',
#    'want',
#    'wall',
#    'outlet',
#    'spare',
#    'usb',
#    'charges',
#    '700mah'], ['stay',
#    'galaxy',
#    'battery',
#    'battery',
#    'rsquo',
#    'samsung',
#    'protective',
#    'slip',
#    'purse',
#    'simply',
#    'charge',
#    'phone',
#    'adapter',
#    'develops',
#    'communications',
#    'mobile',
#    'tablets',
#    'accessories',
#    'five',
#    'samsung',
#    'phone',
#    'products',
#    'genuine',
#    'beware',
#    'small',
#    'provide',
#    'knowing',
#    'replacement',
#    'phone',
#    'durable',
#    'micro',
#    'usb',
#    'compartment',
#    'size',
#    'charger',
#    'charger',
#    'business',
#    'five',
#    'samsung',
#    'discontinued',
#    'low',
#    'swap',
#    'battery',
#    'power',
#    'seconds',
#    'using',
#    'device',
#    'wall',
#    'outlet',
#    'compact',
#    'case'], ['samsung',
#    'included',
#    'charged',
#    'instead',
#    'galaxy',
#    'peace',
#    'charged',
#    'day',
#    'battery',
#    'covered',
#    'durable',
#    'need',
#    'briefcase',
#    'stores',
#    'protects',
#    'spare',
#    'battery',
#    'size',
#    'home',
#    'charger',
#    'charge',
#    'travel',
#    'compatible',
#    'adapter',
#    'markets',
#    'including',
#    'mobile',
#    'tablets',
#    'samsung',
#    'based',
#    'worldwide',
#    'authentic',
#    'purchased',
#    'holographic',
#    'please',
#    'tampered',
#    'reseller',
#    'galaxy',
#    'plug',
#    '2600mah',
#    'view',
#    'pocket',
#    'view',
#    'let',
#    'battery',
#    'mind',
#    'knowing',
#    'backup',
#    'spare',
#    'battery',
#    'features',
#    'durable',
#    'case',
#    'charged',
#    'bag',
#    'battery',
#    'usb',
#    'charger',
#    'mobiles',
#    'simply',
#    'charge',
#    'home',
#    'battery',
#    'standard',
#    'battery',
#    'mah',
#    'charger',
#    'samsung',
#    'markets',
#    'business',
#    'including',
#    'verizon',
#    'recognized',
#    'world',
#    'loyalty',
#    'phones',
#    'samsung',
#    'included',
#    'phone',
#    'dead',
#    '2600mah',
#    'great',
#    'want',
#    'wall',
#    'outlet',
#    'compact',
#    'spare',
#    'micro',
#    'compatible'], ['battery',
#    'stay',
#    'battery',
#    'provide',
#    'spare',
#    'spare',
#    'charged',
#    'stores',
#    'compartment',
#    'middot',
#    'battery',
#    'travel',
#    '700mah',
#    'business',
#    'associated',
#    'past',
#    'loyalty',
#    'receive',
#    'product',
#    'samsung',
#    'galaxy',
#    'storage',
#    'compartment',
#    'briefcase',
#    'peace',
#    'need',
#    'battery',
#    'need',
#    'spare',
#    'protective',
#    'charged',
#    'purse',
#    'usb',
#    'cable',
#    'battery',
#    'based',
#    'manufacturer',
#    'mobile',
#    'samsung',
#    'discontinued',
#    'battery',
#    'charger',
#    'battery',
#    'outlet',
#    'charging',
#    'adapter',
#    '700mah'], ['instead',
#    'battery',
#    'spare',
#    'doubles',
#    'protective',
#    'portability',
#    'bag',
#    'bag',
#    'battery',
#    'slip',
#    'charge',
#    'charge',
#    'middot',
#    'develops',
#    'communications',
#    'one',
#    'manufacturer',
#    'packaging',
#    'imitations',
#    'receive',
#    'view',
#    'briefcase',
#    'spare',
#    'replacement',
#    'galaxy',
#    'briefcase',
#    '700mah',
#    'micro',
#    'usb',
#    'spare',
#    'simply',
#    'easy',
#    'charge',
#    'galaxy',
#    'charger',
#    'standard',
#    'markets',
#    'business',
#    'based',
#    'samsung',
#    'samsung',
#    'battery',
#    'included',
#    'dead',
#    'power',
#    'power',
#    'seconds',
#    'using',
#    'outlet',
#    'usb',
#    'also',
#    'charges'], ['samsung',
#    'get',
#    'plan',
#    'slip',
#    'small',
#    'purse',
#    'protects',
#    'spare',
#    'makes',
#    'home',
#    'home',
#    'charge',
#    '2600mah',
#    'adapter',
#    'mobiles',
#    'samsung',
#    'corporation',
#    'markets',
#    'mobile',
#    'number',
#    'phones',
#    'sticker',
#    'signifying',
#    'product',
#    'existent',
#    'plug',
#    'cable',
#    'larger',
#    'fit',
#    'always',
#    'battery',
#    'accessory',
#    'durable',
#    'sleeker',
#    'samsung',
#    'storage',
#    'compartment',
#    'standard',
#    'battery',
#    'micro',
#    'models',
#    'samsung',
#    'phone',
#    'mobile',
#    'samsung',
#    'galaxy',
#    'battery',
#    'simply',
#    'seconds',
#    'continue',
#    'wall',
#    'outlet',
#    'case',
#    'adapter',
#    '700mah'], ['charged',
#    'mind',
#    'charger',
#    'whether',
#    'mind',
#    'durable',
#    'charging',
#    'battery',
#    'storage',
#    'plug',
#    'home',
#    'charge',
#    'charger',
#    'business',
#    'communications',
#    'loyalty',
#    'mobile',
#    'worldwide',
#    'authentic',
#    'samsung',
#    'battery',
#    'included',
#    '2600mah',
#    'slowed',
#    'battery',
#    'always',
#    'charged',
#    'pocket',
#    'used',
#    'spare',
#    'size',
#    'makes',
#    'variety',
#    'associated',
#    'accessories',
#    'five',
#    'samsung',
#    'battery',
#    'discontinued',
#    'charger',
#    '2600mah',
#    'included',
#    'low',
#    'seconds',
#    'great',
#    'wall',
#    'spare',
#    'battery',
#    'also'], ['battery',
#    'included',
#    'get',
#    'downed',
#    'mind',
#    'knowing',
#    '2600mah',
#    'backup',
#    'samsung',
#    'doubles',
#    'pocket',
#    'bag',
#    'middot',
#    'middot',
#    'home',
#    'battery',
#    'micro',
#    'mobiles',
#    'samsung',
#    'mobile',
#    'phone',
#    'world',
#    'genuine',
#    'visible',
#    'genuine',
#    'imitations',
#    'receive',
#    'removed',
#    'sticker',
#    'samsung',
#    'cable',
#    'compact',
#    'new',
#    'sleeker',
#    'pocket',
#    'additional',
#    'micro',
#    'simply',
#    'samsung',
#    'discontinued',
#    'seconds',
#    'wall',
#    'also',
#    'compatible',
#    'adapter',
#    '700mah'], ['galaxy',
#    'inconvenience',
#    'replacement',
#    'battery',
#    'samsung',
#    'small',
#    'protects',
#    'makes',
#    'battery',
#    'phone',
#    'adapter',
#    'mobile',
#    'samsung',
#    'imitations',
#    'battery',
#    'storage',
#    'plug',
#    'larger',
#    'pocket',
#    'larger',
#    'whether',
#    'charger',
#    'features',
#    'mind',
#    'protective',
#    'slip',
#    'bag',
#    'pocket',
#    'charger',
#    'simply',
#    'size',
#    'charger',
#    '2600',
#    'amp',
#    'carriers',
#    'researches',
#    'samsung',
#    'galaxy',
#    'seconds',
#    'continue',
#    'outlet',
#    'battery',
#    'travel',
#    'charges'], ['slowed',
#    '2600mah',
#    'galaxy',
#    'battery',
#    'small',
#    'bag',
#    'battery',
#    'cable',
#    'battery',
#    'middot',
#    'compatible',
#    'phone',
#    'manufacturer',
#    'communications',
#    'mobile',
#    'products',
#    'samsung',
#    'product',
#    'purchased',
#    'product',
#    'battery',
#    'view',
#    'bag',
#    'pocket',
#    'galaxy',
#    'plan',
#    'samsung',
#    'charged',
#    'portability',
#    'case',
#    'compact',
#    'charger',
#    'galaxy',
#    'compatible',
#    'phone',
#    'spare',
#    'cable',
#    'size',
#    'charge',
#    'battery',
#    'amp',
#    'mobile',
#    'world',
#    'customer',
#    'samsung',
#    'battery',
#    'discontinued',
#    'galaxy',
#    'charger',
#    'wall',
#    'outlet',
#    'charging',
#    'charges',
#    'adapter']],
#  (8, 1480): [['packaging', 'defense', 'ports', 'jacks'],
#   ['gunmetal', 'screen', 'covers', 'hands'],
#   ['action', 'gunmetal', 'ports', 'works', 'protection'],
#   ['day', 'protection', 'built', 'ports', 'protection'],
#   ['cover', 'protection', 'stop', 'protection', 'protection'],
#   ['brilliant', 'stop', 'screen', 'protection', 'jacks'],
#   ['protector', 'dust', 'protection', 'jacks'],
#   ['protector', 'protection', 'protection'],
#   ['otterbox', 'gunmetal', 'holster', 'jacks'],
#   ['otterbox', 'shell', 'protector', 'flawless', 'port']],
#  (50,
#   465): [['commuter',
#    'easily',
#    'commuter',
#    'life',
#    'phone',
#    'sleek',
#    'layers',
#    'together',
#    'ready',
#    'series',
#    'case',
#    'samsung',
#    'galaxy',
#    'navy',
#    'discontinued',
#    'manufacturer',
#    'gunmetal',
#    'thin',
#    'case',
#    'shock',
#    'covers',
#    'includes',
#    'details',
#    'otterbox',
#    'drop',
#    'protection',
#    'slim'], ['pack',
#    'slim',
#    'case',
#    'fits',
#    'bag',
#    'crevice',
#    'tough',
#    'two',
#    'construction',
#    'safe',
#    'bumps',
#    'plus',
#    'dust',
#    'phone',
#    'plugs',
#    'tough',
#    'protects',
#    'bumps',
#    'shocks',
#    'two',
#    'divert',
#    'device',
#    'series',
#    'case',
#    'packaging',
#    'navy',
#    'discontinued',
#    'otterbox',
#    'thin',
#    'provides',
#    'port',
#    'block',
#    'entry',
#    'debris',
#    'year',
#    'details',
#    'slim'], ['time',
#    'x2019',
#    'slim',
#    'case',
#    'easily',
#    'featuring',
#    'tough',
#    'two',
#    'layer',
#    'construction',
#    'commuter',
#    'helps',
#    'keep',
#    'plugs',
#    'tough',
#    'case',
#    'protects',
#    'scratches',
#    'commuter',
#    'layers',
#    'together',
#    'force',
#    'keeping',
#    'series',
#    'carrier',
#    'navy',
#    'discontinued',
#    'otterbox',
#    'gunmetal',
#    'covers',
#    'see',
#    'scratch',
#    'protection',
#    'dust'], ['x2019',
#    'pack',
#    'slim',
#    'keep',
#    'safe',
#    'inputs',
#    'protection',
#    'divert',
#    'impact',
#    'force',
#    'phone',
#    'series',
#    'samsung',
#    'galaxy',
#    'carrier',
#    'packaging',
#    'navy',
#    'gunmetal',
#    'piece',
#    'case',
#    'provides',
#    'shock',
#    'includes',
#    'website'], ['briefcase',
#    'two',
#    'construction',
#    'dust',
#    'inputs',
#    'plugs',
#    'protection',
#    'commuter',
#    'series',
#    'galaxy',
#    'carrier',
#    'packaging',
#    'navy',
#    'discontinued',
#    'manufacturer',
#    'gunmetal',
#    'dust',
#    'debris',
#    'includes',
#    'details',
#    'authentic',
#    'otterbox'], ['x2019',
#    'along',
#    'sleep',
#    'slim',
#    'easily',
#    'x2014',
#    'construction',
#    'commuter',
#    'series',
#    'helps',
#    'life',
#    'stop',
#    'commuter',
#    'work',
#    'divert',
#    'phone',
#    'commuter',
#    'case',
#    'carrier',
#    'navy',
#    'discontinued',
#    'manufacturer',
#    'otterbox',
#    'thin',
#    'drops',
#    'bumps',
#    'entry',
#    'dust',
#    'slides',
#    'pockets',
#    'includes',
#    'case',
#    'see',
#    'details',
#    'authentic',
#    'slim',
#    'profile'], ['briefcase',
#    'sleep',
#    'fits',
#    'bag',
#    'x2014',
#    'featuring',
#    'layer',
#    'construction',
#    'commuter',
#    'helps',
#    'drops',
#    'life',
#    'dust',
#    'phone',
#    'jacks',
#    'sleek',
#    'protects',
#    'shocks',
#    'series',
#    'case',
#    'protection',
#    'divert',
#    'impact',
#    'samsung',
#    'carrier',
#    'packaging',
#    'discontinued',
#    'otterbox',
#    'gunmetal',
#    'includes',
#    'authentic',
#    'protection',
#    'screen',
#    'protection',
#    'slim',
#    'profile'], ['x2019',
#    'slim',
#    'case',
#    'easily',
#    'tough',
#    'helps',
#    'phone',
#    'safe',
#    'stop',
#    'phone',
#    'stays',
#    'plugs',
#    'sleek',
#    'bumps',
#    'shocks',
#    'series',
#    'series',
#    'galaxy',
#    'carrier',
#    'navy',
#    'discontinued',
#    'otterbox',
#    'gunmetal',
#    'protection',
#    'covers',
#    'block',
#    'entry',
#    'dust',
#    'slides',
#    'year',
#    'website',
#    'warranty',
#    'protection',
#    'profile'], ['pack',
#    'briefcase',
#    'x2019',
#    'slim',
#    'case',
#    'bag',
#    'tough',
#    'two',
#    'layer',
#    'keep',
#    'phone',
#    'safe',
#    'port',
#    'dust',
#    'entering',
#    'inputs',
#    'phone',
#    'stays',
#    'clean',
#    'sleek',
#    'commuter',
#    'case',
#    'work',
#    'device',
#    'commuter',
#    'series',
#    'case',
#    'samsung',
#    'galaxy',
#    'packaging',
#    'navy',
#    'gunmetal',
#    'thin',
#    'lightweight',
#    'provides',
#    'port',
#    'entry',
#    'pockets',
#    'includes',
#    'screen'], ['pack',
#    'briefcase',
#    'sleep',
#    'commuter',
#    'easily',
#    'x2014',
#    'tough',
#    'two',
#    'construction',
#    'commuter',
#    'series',
#    'tough',
#    'scratches',
#    'device',
#    'commuter',
#    'case',
#    'samsung',
#    'galaxy',
#    'packaging',
#    'navy',
#    'discontinued',
#    'gunmetal',
#    'shock',
#    'port',
#    'entry',
#    'includes',
#    '100',
#    'authentic',
#    'warranty',
#    'protection']],
#  (50,
#   1799): [['gear',
#    'products',
#    'spirit',
#    'represent',
#    'cases',
#    'hard',
#    'core',
#    'visually',
#    'striking',
#    'shape',
#    'also',
#    'strength',
#    'design',
#    'allows',
#    'glare',
#    'uncompromised',
#    'materials',
#    'working',
#    'protection',
#    'uag',
#    'month',
#    'light',
#    'composite',
#    'phone',
#    'case',
#    'uag',
#    'composite',
#    'feather',
#    'cases',
#    'resistant',
#    'lip',
#    'pads',
#    'ultra',
#    'responsive',
#    'click',
#    'test',
#    'mil',
#    'skid',
#    'cables',
#    'headphones'], ['light',
#    'core',
#    'unique',
#    'also',
#    'size',
#    'device',
#    'marriage',
#    'light',
#    'cobalt',
#    'military',
#    'tested',
#    'phone',
#    'case',
#    'uag',
#    'provide',
#    'crisp'], ['case',
#    'snapshots',
#    'elements',
#    'device',
#    'feather',
#    'light',
#    'composite',
#    'military',
#    'tested',
#    'case',
#    'uag',
#    'composite',
#    'feather',
#    '810g',
#    'oversized',
#    'cables'], ['quality',
#    'light',
#    'cases',
#    'resistant',
#    'core',
#    'design',
#    'snapshots',
#    'protection',
#    'light',
#    'composite',
#    'military',
#    'drop',
#    'tested',
#    'phone',
#    'impact',
#    'soft',
#    'pads',
#    'buttons',
#    'improved',
#    'meets',
#    'skid',
#    'cables'], ['designers',
#    'cases',
#    'hard',
#    'impact',
#    'visually',
#    'provides',
#    'weight',
#    'minimizing',
#    'design',
#    'allows',
#    'full',
#    'access',
#    'device',
#    'flash',
#    'audio',
#    'working',
#    'colors',
#    'uag',
#    'month',
#    'manufacturer',
#    'warranty',
#    'feather',
#    'military',
#    'tested',
#    'phone',
#    'uag',
#    'light',
#    'shell',
#    'soft',
#    'rubber',
#    'screen',
#    'lip',
#    'provide',
#    'degree',
#    'buttons',
#    'clean',
#    'click',
#    'military',
#    'providing',
#    'increased',
#    'charging'], ['armor',
#    'outer',
#    'soft',
#    'core',
#    'shape',
#    'also',
#    'allows',
#    'elements',
#    'manufacturer',
#    'feather',
#    'light',
#    'composite',
#    'military',
#    'drop',
#    'phone',
#    'case',
#    'core',
#    'screen',
#    'ultra',
#    'feel',
#    'functionality',
#    'protection'], ['armor',
#    'independent',
#    'light',
#    'visually',
#    'striking',
#    'minimizing',
#    'allows',
#    'free',
#    'audio',
#    'snapshots',
#    'elements',
#    'unison',
#    'array',
#    'vibrant',
#    'uag',
#    'month',
#    'feather',
#    'composite',
#    'military',
#    'drop',
#    'phone',
#    'light',
#    'hard',
#    'soft',
#    'buttons',
#    'improved',
#    'meets',
#    'standards',
#    'tactile',
#    'use'], ['reflect',
#    'designers',
#    'dedication',
#    'superior',
#    'craftsmanship',
#    'feather',
#    'cases',
#    'feature',
#    'core',
#    'minimizing',
#    'allows',
#    'controls',
#    'designed',
#    'flash',
#    'design',
#    'elements',
#    'light',
#    'composite',
#    'cobalt',
#    'military',
#    'uag',
#    'cases',
#    'feature',
#    'patented',
#    'resistant',
#    'soft',
#    'responsive',
#    'deliver',
#    'crisp',
#    'clean',
#    '516',
#    'allow'], ['spirit',
#    'superior',
#    'craftsmanship',
#    'feature',
#    'visually',
#    'size',
#    'design',
#    'audio',
#    'snapshots',
#    'uncompromised',
#    'marriage',
#    'materials',
#    'device',
#    'maximizes',
#    'case',
#    'feather',
#    'composite',
#    'cobalt',
#    'military',
#    'drop',
#    'uag',
#    'lip',
#    'improved',
#    'test',
#    'standards',
#    'mil',
#    'use'], ['gear',
#    'products',
#    'independent',
#    'dedication',
#    'feather',
#    'hard',
#    'impact',
#    'resistant',
#    'core',
#    'also',
#    'allows',
#    'access',
#    'flash',
#    'audio',
#    'snapshots',
#    'uncompromised',
#    'device',
#    'maximizes',
#    'uag',
#    'twelve',
#    'light',
#    'composite',
#    'cobalt',
#    'tested',
#    'uag',
#    'light',
#    'cases',
#    'feature',
#    'resistant',
#    'soft',
#    'provide',
#    'protection',
#    'clean',
#    'click',
#    'meets',
#    'providing']],
#  (50,
#   1470): [['series',
#    'innovation',
#    'culmination',
#    'keep',
#    'spectrum',
#    'symmetry',
#    'symmetry',
#    'series',
#    'otterbox',
#    '100',
#    'world'], ['simple',
#    'construction',
#    'symmetry',
#    'series',
#    'symmetry',
#    'series',
#    'black',
#    'otterbox',
#    'sleek',
#    'drops',
#    'customer',
#    'npd'], ['screen',
#    'complete',
#    'slender',
#    'series',
#    'symmetry',
#    'series',
#    'otterbox',
#    'absorbing'], ['class',
#    'raised',
#    'help',
#    'seamless',
#    'want',
#    'need',
#    'symmetry',
#    'series',
#    'otterbox',
#    'withstands',
#    'otterbox',
#    'bumper',
#    'npd'], ['let',
#    'simplicity',
#    'keep',
#    'material',
#    'polycarbonate',
#    'symmetry',
#    'series',
#    'otterbox',
#    'shock',
#    'details',
#    'service'], ['smartphone',
#    'install',
#    'piece',
#    'elegant',
#    'internal',
#    'beveled',
#    'full',
#    'entire',
#    'symmetry',
#    'series',
#    'black',
#    'style',
#    'safe',
#    'absorbs',
#    'withstands',
#    'easy',
#    'protects',
#    'flash'], ['testing',
#    'case',
#    'symmetry',
#    'series',
#    'case',
#    'black',
#    'installation',
#    'phone',
#    '100',
#    '2012',
#    'npd'], ['one',
#    'symmetry',
#    'series',
#    'otterbox',
#    'friendly',
#    'absorbs',
#    'includes',
#    'scratch',
#    'installation'], ['constructed',
#    'cleanly',
#    'symmetry',
#    'series',
#    'otterbox',
#    'friendly',
#    'wraparound',
#    'material',
#    'class',
#    'service',
#    'certified',
#    'installation'], ['material',
#    'beveled',
#    'spectrum',
#    'style',
#    'symmetry',
#    'series',
#    'otterbox',
#    'plus',
#    'withstands',
#    'limited',
#    'warranty',
#    'leading']],
#  (50,
#   1488): [['series',
#    'let',
#    'construction',
#    'makes',
#    'keep',
#    'touch',
#    'shock',
#    'spectrum',
#    'protection',
#    'symmetry',
#    'series',
#    'case',
#    'microsoft',
#    '650',
#    '650',
#    'sim',
#    'otterbox',
#    'lumia',
#    'stylish',
#    'edge',
#    'installation',
#    'easy'], ['innovation',
#    'constructed',
#    'case',
#    'simple',
#    'elegant',
#    'makes',
#    'symmetry',
#    'one',
#    'cases',
#    'touch',
#    'safe',
#    'drops',
#    'beveled',
#    'full',
#    'spectrum',
#    'add',
#    'look',
#    'symmetry',
#    'microsoft',
#    '650',
#    'dual',
#    'sim',
#    'otterbox',
#    'sleek',
#    'pocket',
#    'design',
#    'stylish',
#    'colors',
#    'add',
#    'wraparound',
#    'construction',
#    'shock',
#    'drops',
#    'absorbs',
#    'keeps',
#    'easy',
#    'installation',
#    'phone',
#    'synthetic',
#    'drop',
#    'protection',
#    'screen',
#    'lumia'], ['case',
#    'let',
#    'protective',
#    'screen',
#    'device',
#    'honeycomb',
#    'coring',
#    'look',
#    'seamless',
#    'symmetry',
#    'microsoft',
#    '650',
#    'dual',
#    'sim',
#    'retail',
#    'packaging',
#    'black',
#    'graphics',
#    'wraparound',
#    'touchscreen',
#    'easy',
#    'protects',
#    'stylizes',
#    'device',
#    '650',
#    'certified',
#    'protection',
#    'scratch',
#    'absorbing',
#    'polycarbonate'], ['symmetry',
#    'culmination',
#    'constructed',
#    'cleanly',
#    'simplicity',
#    'fool',
#    'edge',
#    'helps',
#    'screen',
#    'material',
#    'help',
#    'graphics',
#    'sleek',
#    'look',
#    'slender',
#    'symmetry',
#    'symmetry',
#    'case',
#    'microsoft',
#    '650',
#    'dual',
#    'retail',
#    'black',
#    'wraparound',
#    'compatible',
#    'device',
#    'material',
#    'drop',
#    'protection',
#    'protection'], ['series',
#    'smartphone',
#    'one',
#    'full',
#    'exterior',
#    'wraparound',
#    'series',
#    'style',
#    'symmetry',
#    'case',
#    'microsoft',
#    'sim',
#    'retail',
#    'packaging',
#    'black',
#    'lumia',
#    'raised',
#    'touchscreen',
#    'protects',
#    'compatible',
#    'protection',
#    'easy'], ['sleek',
#    'cleanly',
#    'dual',
#    'material',
#    'helps',
#    'device',
#    'look',
#    'series',
#    'style',
#    'symmetry',
#    'microsoft',
#    'dual',
#    'sim',
#    'retail',
#    'packaging',
#    'lumia',
#    'design',
#    'seamless',
#    'keeps',
#    'easy',
#    'screen',
#    'easy'], ['innovation',
#    'culmination',
#    'constructed',
#    'cleanly',
#    'simplicity',
#    'symmetry',
#    'helps',
#    'keep',
#    'internal',
#    'symmetry',
#    'series',
#    'symmetry',
#    'case',
#    'microsoft',
#    '650',
#    'retail',
#    'packaging',
#    'lumia',
#    'friendly',
#    'drops',
#    'absorbs',
#    'touchscreen',
#    'material',
#    'scratch',
#    'absorbing',
#    'easy',
#    'lumia',
#    'polycarbonate'], ['design',
#    'innovation',
#    'sleek',
#    'smartphone',
#    'beveled',
#    'spectrum',
#    'colors',
#    'symmetry',
#    'series',
#    'microsoft',
#    '650',
#    'sim',
#    'retail',
#    'black',
#    'otterbox',
#    'colors',
#    'drops',
#    'absorbs',
#    '650',
#    'screen',
#    'bumper',
#    'absorbing'], ['year',
#    'keep',
#    'touch',
#    'complete',
#    'polycarbonate',
#    'symmetry',
#    'case',
#    '650',
#    'dual',
#    'sim',
#    'packaging',
#    'otterbox',
#    'lumia',
#    'drops',
#    'safe',
#    'installation'], ['case',
#    'simplicity',
#    'material',
#    'dont',
#    'raised',
#    'edge',
#    'touch',
#    'graphics',
#    'polycarbonate',
#    'symmetry',
#    'style',
#    'symmetry',
#    'series',
#    'case',
#    'microsoft',
#    'dual',
#    'retail',
#    'lumia',
#    'material',
#    'absorbs',
#    'withstands',
#    'keeps',
#    'certified',
#    'screen']],
#  (50, 1311): [['work', 'phone', 'purple', 'purple', 'piece', 'protection'],
#   ['galaxy', 'purple', 'purple', 'amethyst', 'protection', 'seamless'],
#   ['purple', 'purple', 'purple', 'includes', 'profile'],
#   ['case', 'impact', 'purple', 'purple', 'block', 'dust'],
#   ['device',
#    'purple',
#    'purple',
#    'slides',
#    'details',
#    'protection',
#    'seamless'],
#   ['protection', 'together', 'galaxy', 'purple', 'purple', 'website'],
#   ['divert', 'galaxy', 'purple', 'purple', 'authentic', 'protection'],
#   ['case', 'impact', 'keeping', 'ready', 'purple', 'purple', 'protection'],
#   ['protection',
#    'force',
#    'purple',
#    'liberty',
#    'purple',
#    'enhanced',
#    'design',
#    'texturing'],
#   ['sleek', 'scratches', 'work', 'ready', 'purple', 'purple']],
#  (57,
#   1449): [['case',
#    'testament',
#    'included',
#    'screen',
#    'series',
#    'limited',
#    'iphone',
#    'onyx',
#    'iphone',
#    'one',
#    'piece',
#    'includes',
#    'limited'], ['strada',
#    'limited',
#    'glass',
#    'iphone',
#    'onyx',
#    'iphone',
#    'samsung',
#    'case',
#    'slim',
#    'sleek',
#    'friendly',
#    'vertical',
#    'place',
#    'installation',
#    'one',
#    'slips',
#    'website',
#    'polycarbonate'], ['mill',
#    'fortified',
#    'life',
#    'edition',
#    'iphone',
#    'retail',
#    'packaging',
#    'friendly',
#    'cardholder',
#    'protection',
#    'provide',
#    'slips',
#    'details',
#    'iphone',
#    'metallic'], ['accents',
#    'strada',
#    'strada',
#    'included',
#    'entire',
#    'limited',
#    'iphone',
#    'leather',
#    'onyx',
#    'plus',
#    'slot',
#    'piece',
#    'lifetime',
#    'website',
#    'details',
#    'rubber'], ['case',
#    'exclusive',
#    'included',
#    'edition',
#    'iphone',
#    'retail',
#    'packaging',
#    'onyx',
#    'plus',
#    'samsung',
#    'vertical',
#    'slot',
#    'place',
#    'dual',
#    'otterbox',
#    'iphone',
#    'shell'], ['metallic',
#    'statement',
#    'phone',
#    'series',
#    'case',
#    'iphone',
#    'packaging',
#    'strada',
#    'iphone',
#    'leather',
#    'samsung',
#    'pocket',
#    'protection',
#    'one',
#    'flash',
#    'warranty'], ['ultra',
#    'statement',
#    'limited',
#    'alpha',
#    'case',
#    'iphone',
#    'retail',
#    'packaging',
#    'trusted',
#    'details',
#    'metallic'], ['mill',
#    'edition',
#    'glass',
#    'limited',
#    'edition',
#    'iphone',
#    'retail',
#    'packaging',
#    'genuine'], ['protection',
#    'fabulous',
#    'limited',
#    'iphone',
#    'retail',
#    'otterbox',
#    'onyx',
#    'genuine',
#    'details',
#    'synthetic',
#    'hunting'], ['metallic',
#    'limited',
#    'included',
#    'protector',
#    'covered',
#    'series',
#    'edition',
#    'alpha',
#    'iphone',
#    'strada',
#    'genuine',
#    'pocket',
#    'cards',
#    'provide',
#    'protection',
#    'case',
#    'fishing']],
#  (57,
#   1047): [['phone',
#    'iphone',
#    'packaging',
#    'rose',
#    'white',
#    'port',
#    'covers',
#    'dust',
#    'easily',
#    'drop',
#    'protection',
#    'protection',
#    'protection'], ['briefcase',
#    'sleep',
#    'commuter',
#    'port',
#    'plugs',
#    'iphone',
#    'case',
#    'neon',
#    'white',
#    'pink',
#    'otterbox',
#    'screen',
#    'protection',
#    'block',
#    'easily',
#    'protection'], ['construction',
#    'series',
#    'inputs',
#    'plugs',
#    'series',
#    'iphone',
#    'case',
#    'packaging',
#    'white',
#    'blaze',
#    'pink',
#    'pockets',
#    'website'], ['fits',
#    'safe',
#    'plugs',
#    'jacks',
#    'series',
#    'iphone',
#    'packaging',
#    'rose',
#    'otterbox',
#    'iphone',
#    'piece',
#    'protection',
#    'bumps',
#    'scratch',
#    'protection',
#    'easy'], ['stop',
#    'series',
#    'iphone',
#    'packaging',
#    'white',
#    'pink',
#    'otterbox',
#    'compatible',
#    'iphone',
#    'port',
#    'protection'], ['briefcase',
#    'commuter',
#    'case',
#    'fits',
#    'featuring',
#    'helps',
#    'safe',
#    'bumps',
#    'plus',
#    'stays',
#    'plugs',
#    'jacks',
#    'iphone',
#    'come',
#    'screen',
#    'piece',
#    'provides',
#    'protection',
#    'port',
#    'includes',
#    'limited',
#    'see',
#    'website',
#    'details',
#    'otterbox',
#    'protection'], ['easily',
#    'fits',
#    'bumps',
#    'plus',
#    'inputs',
#    'jacks',
#    'series',
#    'iphone',
#    'white',
#    'blaze',
#    'screen',
#    'protector',
#    'pockets',
#    'protection'], ['fits',
#    'crevice',
#    'two',
#    'construction',
#    'commuter',
#    'series',
#    'keep',
#    'entering',
#    'jacks',
#    'iphone',
#    'white',
#    'screen',
#    'provides',
#    'lifetime',
#    'see',
#    'authentic',
#    'otterbox',
#    'screen',
#    'protection',
#    'scratch',
#    'protection',
#    'easy',
#    'functionality'], ['two',
#    'construction',
#    'helps',
#    'life',
#    'stop',
#    'iphone',
#    'neon',
#    'rose',
#    'white',
#    'protector',
#    'bumps',
#    'block',
#    'entry',
#    'authentic',
#    'otterbox',
#    'warranty',
#    'protection'], ['plugs',
#    'commuter',
#    'series',
#    'neon',
#    'rose',
#    'whisper',
#    'white',
#    'pink',
#    'otterbox',
#    'protector',
#    'see',
#    'warranty',
#    'protection',
#    'dust',
#    'slim',
#    'functionality']],
#  (57, 1460): [['packaging', 'iphone', 'sleek', 'raised', 'limited'],
#   ['iphone', 'style', 'protects'],
#   ['iphone', 'iphone', 'plus', 'seamless', 'dual', 'details'],
#   ['plus', 'protection', 'iphone', 'graphics', 'add', 'style'],
#   ['product', 'statement', 'date', 'thin', 'seamless'],
#   ['iphone', 'lifetime', 'warranty'],
#   ['product', 'iphone', 'friendly', 'wraparound'],
#   ['night', 'polka', 'style', 'iphone', 'iphone'],
#   ['iphone', 'material', 'plus', 'beveled'],
#   ['phone', 'iphone', 'wraparound', 'website', 'warranty']],
#  (57, 659): [['frame', 'kyasi'],
#   ['gladiator'],
#   ['gladiator', 'technology'],
#   ['kyasi'],
#   ['protector', 'kyasi'],
#   ['kyasi'],
#   ['gladiator'],
#   ['screen', 'protection'],
#   ['protector', 'kyasi'],
#   ['gladiator']],
#  (80,
#   1219): [['precision',
#    'iphone',
#    'aluminum',
#    '165',
#    'angle',
#    'telephoto',
#    'ultra'], ['high',
#    'iphone',
#    'aluminum',
#    'aluminum',
#    'lens',
#    'bracket',
#    'easily'], ['bracket',
#    'tripods',
#    'iphone',
#    'aluminum',
#    'soft',
#    'easily'], ['selfie', 'iphone', 'aluminum', 'dynamic', 'perfect', 'fit', 'covers'], ['mount',
#    'iphone',
#    'aluminum',
#    'features',
#    'mount',
#    'iphone',
#    'selfie',
#    'soft',
#    'tripods'], ['quickly',
#    'photos',
#    'iphone',
#    'aluminum',
#    'wide',
#    'perfect'], ['lenses',
#    'integrated',
#    'capture',
#    'iphone',
#    'aluminum',
#    'photos',
#    'includes',
#    'iphone',
#    'machined'], ['exolens',
#    'high',
#    'iphone',
#    'aluminum',
#    'high',
#    'integrated',
#    '165',
#    'aluminum',
#    'ensures'], ['aluminum',
#    'capture',
#    'iphone',
#    'aluminum',
#    'lining'], ['wide', 'bracket', 'iphone', 'aluminum', 'precision']],
#  (80,
#   1318): [['charge',
#    'charging',
#    'including',
#    'edge',
#    'charging',
#    'samsung',
#    'international',
#    'reliable',
#    'cable'], ['charging',
#    'including',
#    'wireless',
#    'edge',
#    'daydream',
#    'samsung',
#    'wireless',
#    'enabled',
# ...
#   ['shock', 'absorbent', 'together', 'iphone', 'defense'],
#   ['grade', 'tpe', 'sleek', 'iphone', 'iphone', 'red', 'protection'],
#   ['military', 'layers', 'slim', 'iphone', 'iphone', 'premium'],
#   ['combining', 'defense', 'slip', 'iphone', 'layers', 'provides'],
#   ['grip', 'iphone', 'iphone', 'touch'],
#   ['device', 'sleek', 'apple', 'iphone'],
#   ['military', 'device', 'iphone', 'iphone'],
#   ['convenience', 'iphone', 'red', 'absorbing', 'premium'],
#   ['iphone', 'layers', 'tear', 'provides', 'premium']],
#  (183, 1463): [['along', 'case', 'pink', 'screen', 'protection', 'npd'],
#   ['pack', 'helps', 'series', 'protection', 'slim'],
#   ['briefcase', 'bubblegum', 'thin', 'piece', 'protection'],
#   ['commuter', '53330', 'bubblegum', 'easily', 'service', 'functionality'],
#   ['bag', 'inputs', 'clean', 'series', 'protection', 'see'],
#   ['series', 'shell', 'protection', 'slim', 'easy'],
#   ['series', 'case', 'block', 'otterbox'],
#   ['series', 'helps', 'bubblegum', 'lifetime', 'adhesive'],
#   ['fits', 'stop', 'phone', 'plugs', 'series', 'drops'],
#   ['bubblegum', 'lightweight', 'entry', 'details', 'authentic']],
#  (183, 1475): [['packaging'],
#   ['bulk'],
#   ['making', 'packaging'],
#   ['polycarbonate', 'bulk'],
#   ['defender', 'packaging'],
#   ['protection', 'packaging'],
#   ['iphone', 'iphone'],
#   ['packaging', 'device'],
#   ['packaging'],
#   ['packaging', 'plus']],
#  (183,
#   791): [['new',
#    'youll',
#    'take',
#    'finger',
#    'quickly',
#    'browse',
#    'enjoy',
#    'shop',
#    'know',
#    'samsung',
#    'galaxy',
#    'white',
#    'kitkat'], ['photos',
#    'camera',
#    'heart',
#    'steps',
#    'style',
#    'never',
#    'galaxy',
#    'galaxy',
#    'connectivity',
#    'available',
#    'darker',
#    'cable',
#    'samsung',
#    'white',
#    '16gb'], ['simply',
#    'roar',
#    'capture',
#    'touch',
#    'partner',
#    'steps',
#    'challenge',
#    'unlock',
#    'moreall',
#    'come',
#    'life',
#    'device',
#    'kitkat'], ['games',
#    'smarter',
#    'smart',
#    'ever',
#    'stream',
#    'everything',
#    'power',
#    'white',
#    'nonessential',
#    'samsung',
#    '16gb',
#    'processor',
#    'kitkat'], ['second',
#    'heartbeat',
#    'galaxy',
#    'new',
#    'badges',
#    'demand',
#    'digging',
#    'garden',
#    'quickly',
#    'quickest',
#    'miss',
#    'important',
#    'black',
#    'quick',
#    'start',
#    'samsung',
#    'white',
#    '16gb',
#    'camera',
#    'android'], ['16gb',
#    'samsung',
#    'switch',
#    'freedom',
#    'perfect',
#    'friends',
#    'earn',
#    'water',
#    'galaxy',
#    'response',
#    'cant',
#    'usb',
#    'white',
#    'camera',
#    'speed'], ['life',
#    'personal',
#    'second',
#    'responds',
#    'faster',
#    'crowded',
#    'hdtv',
#    'viewing',
#    'samsung',
#    'kitkat'], ['impacts',
#    'freedom',
#    'fear',
#    'shots',
#    'badges',
#    'nutrition',
#    'never',
#    'dustproof',
#    'easier',
#    'allows',
#    'quickest',
#    'combines'], ['second',
#    'fear',
#    'weve',
#    'perfect',
#    'steps',
#    'galaxy',
#    'look',
#    'work',
#    'life',
#    'leading',
#    'timesall',
#    'white',
#    '16gb'], ['second',
#    'workout',
#    'functional',
#    'moreall',
#    'allows',
#    'combines',
#    'display',
#    'faster',
#    'calls',
#    'wall',
#    'guide',
#    'android']],
#  (267, 183): [['pink', 'bumper', 'apple', 'premium', 'apple', 'iphone'],
#   ['black', 'premium', 'bumper', 'case'],
#   ['black',
#    'premium',
#    'case',
#    'apple',
#    'specifically',
#    'iphone',
#    'convenient',
#    'remove'],
#   ['premium', 'case', 'apple', 'iphone'],
#   ['bumper', 'case', 'apple', 'iphone', 'apple', 'iphone'],
#   ['premium', 'bumper', 'apple', 'iphone', 'iphone', 'protects'],
#   ['premium', 'bumper', 'apple', 'iphone', 'verizon', 'new'],
#   ['premium', 'case', 'apple', 'apple', 'iphone'],
#   ['premium', 'bumper', 'sanoxy', 'case', 'apple', 'iphone', 'new'],
#   ['bumper', 'case', 'apple', 'apple', 'protects']],
#  (267,
#   333): [['easier',
#    'code',
#    'case',
#    'help',
#    'iphone',
#    'smartphone',
#    'findables',
#    'finish'], ['comes',
#    'application',
#    'findables',
#    'happen',
#    'iphone',
#    'smartphone',
#    'app',
#    'findables',
#    'share',
#    'piece',
#    'full',
#    'buttons',
#    'minimalist'], ['application',
#    'business',
#    'instant',
#    'iphone',
#    'smartphone',
#    'glow',
#    'connect',
#    'one',
#    'access'], ['colored',
#    'code',
#    'devices',
#    'iphone',
#    'smartphone',
#    'glow',
#    'design',
#    'allows',
#    'finish'], ['iphone',
#    'devices',
#    'findables',
#    'iphone',
#    'smartphone',
#    'glow',
#    'contact',
#    'design',
#    'access'], ['customize',
#    'iphone',
#    'smartphone',
#    'glow',
#    'findables',
#    'share',
#    'connect'], ['iphone',
#    'findables',
#    'case',
#    'mobile',
#    'iphone',
#    'smartphone',
#    'profiles',
#    'allows',
#    'access',
#    'buttons',
#    'shell',
#    'resistant'], ['makes',
#    'application',
#    'code',
#    'misplace',
#    'iphone',
#    'smartphone',
#    'findables',
#    'information'], ['information',
#    'mobile',
#    'iphone',
#    'smartphone',
#    'case',
#    'glow',
#    'findables',
#    'share',
#    'phone',
#    'one',
#    'access',
#    'shell'], ['instant',
#    'information',
#    'iphone',
#    'smartphone',
#    'app',
#    'full',
#    'access',
#    'resistant']],
#  (267, 192): [['frame', 'iphone', 'clear', 'conveniently'],
#   ['frame', 'apple', 'iphone', 'anti'],
#   ['apple', 'iphone', 'perfectly'],
#   ['apple', 'iphone', 'skidding', 'fits'],
#   ['apple', 'iphone', 'conveniently'],
#   ['cover', 'apple', 'iphone'],
#   ['iphone', 'iphone', 'clear'],
#   ['quality', 'apple', 'iphone'],
#   ['apple', 'iphone', 'interface'],
#   ['apple', 'iphone', 'available']],
#  (267, 1469): [['device', 'packaging', 'built', 'included'],
#   ['packaging', 'marthoner', 'protective'],
#   ['calls', 'packaging'],
#   ['film', 'otterbox', 'guards'],
#   ['packaging', 'guards', 'website', 'protection'],
#   ['series', 'works', 'packaging', 'belt'],
#   ['screen', 'calls', 'google', 'otterbox'],
#   ['packaging', 'dust', 'protection'],
#   ['built', 'packaging', 'layer', 'protector'],
#   ['texts', 'case', 'retail', 'free', 'includes']],
#  (267, 1069): [['world', 'body', 'anti', 'coating', 'maximum', 'inch'],
#   ['maxboost', 'camera', 'free', 'scratches', 'plus'],
#   ['perfect', 'buttons', 'camera', 'warranty'],
#   ['maxboost', 'maximum', 'pocket', 'buttons', 'warranty', 'original'],
#   ['clear', 'iphone', 'resistance'],
#   ['use', 'case', 'beauty', 'rsquo', 'perfect', 'world'],
#   ['maxboost', 'original', 'wear', 'thinnest', 'warranty'],
#   ['pocket', 'buttons', 'feels', 'warranty'],
#   ['world', 'perfect', 'lifetime', 'ensure', 'maxboost', 'plus'],
#   ['please', 'iphone', 'world', 'thinnest', 'iphone', 'scrapes']],
#  (283,
#   368): [['life',
#    'audio',
#    'micro',
#    'iphone',
#    'iphone',
#    'indicator',
#    'battery'], ['truly',
#    'redirects',
#    'indicator',
#    'helium',
#    'iphone',
#    'mophie',
#    'charged',
#    'iphone'], ['believe',
#    'helium',
#    'elegant',
#    'optimizing',
#    'juice',
#    'iphone',
#    'life',
#    '1500mah'], ['juice',
#    'safe',
#    'allows',
#    'enhanced',
#    'ready',
#    'juice',
#    'iphone',
#    'iphone',
#    'iphone'], ['iphone',
#    'life',
#    'led',
#    'indicator',
#    'battery',
#    'levels',
#    'compatible',
#    'iphone'], ['palm',
#    'believe',
#    'usb',
#    'iphone',
#    'iphone',
#    'simultaneously',
#    'juice',
#    'indicator',
#    'apple'], ['ultra',
#    'battery',
#    'design',
#    'pack',
#    'juice',
#    'iphone',
#    'led',
#    'indicator'], ['accessory',
#    'indicator',
#    'use',
#    'included',
#    'iphone',
#    'battery',
#    'case',
#    'indicator',
#    'battery'], ['1500mah',
#    'juice',
#    'also',
#    'iphone',
#    'protective',
#    'simultaneously',
#    'led'], ['packs',
#    'battery',
#    'also',
#    'iphone',
#    'iphone',
#    'iphone',
#    'iphone',
#    'indicator']],
#  (283,
#   1419): [['enjoy',
#    'take',
#    'lanyard',
#    'iphone',
#    'galaxy',
#    'inch',
#    'clear',
#    'device',
#    'protects',
#    'material',
#    'also'], ['apple',
#    'kayaking',
#    'cameras',
#    'iphone',
#    'galaxy',
#    'note',
#    'device',
#    'pda',
#    'strap'], ['using',
#    'case',
#    'iphone',
#    'galaxy',
#    'one',
#    'itouch',
#    'water',
#    'sand',
#    'hand',
#    'cards'], ['one',
#    'm10',
#    'mini',
#    'iphone',
#    'galaxy',
#    'fits',
#    'devices',
#    'keep',
#    'cards',
#    'protects'], ['activities',
#    'bag',
#    'mini',
#    'iphone',
#    'devices',
#    'functionality',
#    'snow',
#    'dirt',
#    'keys',
#    'accessories'], ['take',
#    'iphone',
#    'galaxy',
#    'note',
#    'taking',
#    'material',
#    'feeling'], ['smartphone',
#    'outdoor',
#    'hiking',
#    'iphone',
#    'galaxy',
#    'window',
#    'water',
#    'composed',
#    'grease',
#    'money',
#    'thermoplastic'], ['devices',
#    'iphone',
#    'beach',
#    'water',
#    'fits',
#    'galaxy',
#    'device',
#    'dirt',
#    'phones'], ['videos',
#    'water',
#    'mini',
#    'iphone',
#    'pda',
#    'cards',
#    'money'], ['smartphone', 'outdoor', 'outdoor', 'fishing', 'iphone', 'galaxy', 'feet', 'smartphones', 'pda', 'also']],
#  (283, 851): [['sharpest', 'motorola', 'comfortably', 'compatible', 'sprint'],
#   ['motorola', 'wall', 'talk'],
#   ['corning', 'motorola', 'networks', 'carriers'],
#   ['display', 'motorola', 'like', 'like', 'cdma'],
#   ['gorilla', 'motorola', 'moto'],
#   ['sharpest', 'motorola', 'gorilla', 'unlocked'],
#   ['motorola', 'including', 'resistant', 'shells', 'cell'],
#   ['motorola', 'straight', 'prepaid'],
#   ['featuring', 'corning', 'motorola', 'battery', '1980mah', 'boost'],
#   ['motorola', 'fits', 'unlocked']],
#  (283,
#   1372): [['frame',
#    'protection',
#    'semi',
#    'iphone',
#    'adds',
#    'protection',
#    'additional',
#    'cutouts',
#    'iphone'], ['provides',
#    'rubberized',
#    'maximum',
#    'iphone',
#    'black',
#    'frame',
#    'precision',
#    'ring',
#    'protection',
#    'port',
#    'maxboost'], ['frame',
#    'additional',
#    'iphone',
#    'anti',
#    'work',
#    '2014',
#    'protection',
#    'protection',
#    'drops',
#    'protection',
#    'dual',
#    'offered'], ['two',
#    'casing',
#    'ergonomic',
#    'marks',
#    'scrapes',
#    'iphone',
#    'clear',
#    'ports',
#    'maxboost'], ['extra',
#    'matte',
#    'casing',
#    'drops',
#    'anti',
#    'protection',
#    'iphone',
#    'protection',
#    'day',
#    'warranty'], ['absorbing',
#    'marks',
#    'buttons',
#    'cutouts',
#    'iphone',
#    'drop',
#    'case',
#    '3uufm5bl',
#    'apply'], ['protection',
#    'falls',
#    'cutouts',
#    'lifetime',
#    'hassle',
#    'iphone',
#    'matte',
#    'scratches',
#    'ports',
#    'buttons',
#    'case'], ['frame',
#    'frame',
#    'drop',
#    'body',
#    'cutouts',
#    'case',
#    'charger',
#    'checkout'], ['grip',
#    'iphone',
#    'matte',
#    'absorbing',
#    'ports',
#    'iphone',
#    'ergonomic',
#    'ring',
#    'maxboost'], ['provides',
#    'inch',
#    'body',
#    'flash',
#    'protection',
#    'protection',
#    'easy',
#    'powerful',
#    'port',
#    'cart']],
#  (283,
#   552): [['kaisi',
#    'transform',
#    'long',
#    'convenient',
#    'assured',
#    'sim',
#    'cutter',
#    'year'], ['makes', 'card', 'high', 'double', 'used'], ['card',
#    'set',
#    'matching',
#    'micro',
#    'assured',
#    'families',
#    'offers',
#    'diy'], ['mirco',
#    'sim',
#    'sumsung',
#    'long',
#    'top',
#    'far',
#    'offers'], ['card', 'product', 'standard', 'standard', 'sim', 'million', 'families'], ['ipad',
#    'make',
#    'cutter',
#    'similar',
#    'families',
#    'offers'], ['product', 'fully', 'far', 'join', 'unconditional'], ['cutter',
#    'card',
#    'steel',
#    'extends',
#    'makes'], ['card',
#    'makes',
#    'series',
#    'matching',
#    'life',
#    'cutter'], ['well', 'card', 'card', 'easily', 'use', 'extends', 'shear']],
#  (57,
#   491): [['app',
#    'combine',
#    'power',
#    'iphone',
#    'ipod',
#    'device',
#    'information',
#    'stored',
#    'enjoys',
#    'use',
#    'simply',
#    'download',
#    'app',
#    'device',
#    'games',
#    'even',
#    'reality',
#    'breakthrough',
#    'app',
#    'turns',
#    'ultimate',
#    'creativity',
#    'works',
#    'ipod',
#    'work',
#    'leappad',
#    'create',
#    'stretch',
#    'imagination',
#    'designed',
#    'little',
#    'mind',
#    'camera',
#    'protective',
#    'combine',
#    'camera',
#    'touch',
#    'pictures',
#    'albums',
#    'even',
#    'exciting',
#    'reality',
#    'leapfrog',
#    'toy',
#    'ultimate',
#    'creativity',
#    'works',
#    '5th',
#    'sold',
#    'appropriate',
#    'children',
#    'ages',
#    'away',
#    'case',
#    'modes',
#    'shots',
#    'silly',
#    'unlocks',
#    'view',
#    'fun',
#    'creativity',
#    'easily',
#    'view',
#    'photos',
#    'use',
#    'one',
#    'letters',
#    'facial',
#    'expressions',
#    'camerafor',
#    'peekabug',
#    'protective',
#    'turns',
#    'iphone',
#    'fun',
#    'camera',
#    'apple',
#    'case',
#    'personal',
#    'become',
#    'child',
#    'hours',
#    'using',
#    'thats',
#    'place',
#    'protective',
#    'case',
#    'creativity',
#    'preschool',
#    'environment',
#    'created',
#    'environment',
#    'appropriate',
#    'ages',
#    'developmentally',
#    'touch',
#    'number',
#    'reinforces',
#    'aspirational',
#    'visual',
#    'visual',
#    'like',
#    'age',
#    'stimulate',
#    'leapfrog',
#    'approach',
#    'camera',
#    'self',
#    'expression',
#    'beyond',
#    'picture',
#    'taking',
#    'picture',
#    'photo',
#    'matching',
#    'action',
#    'creativity',
#    'protective',
#    'touch',
#    'generation',
#    'separately',
#    'leapfrog',
#    'check',
#    'app',
#    'ipod',
#    'learn',
#    'new',
#    'interactive',
#    'creativity',
#    'camera',
#    'case',
#    'iphone',
#    'touch',
#    'camera',
#    'helps',
#    'create',
#    'express',
#    'included',
#    'creativity',
#    'app',
#    'work',
#    'ultimate',
#    'creativity',
#    'camera',
#    'includes',
#    'learning',
#    'app',
#    'protective',
#    'green',
#    'case',
#    'leapfrog',
#    'teaches',
#    'creativity',
#    'curriculum',
#    'activities',
#    'game',
#    'experience'], ['photos',
#    'camera',
#    'app',
#    'touch',
#    'simply',
#    'creativity',
#    'children',
#    'make',
#    'pictures',
#    'age',
#    'works',
#    'leapster',
#    'features',
#    'create',
#    'stretch',
#    'photos',
#    'iphone',
#    'modes',
#    'missions',
#    'augmented',
#    'leapfrog',
#    'device',
#    'ultimate',
#    '4th',
#    'systems',
#    'leappad',
#    'ages',
#    'shots',
#    'photos',
#    'works',
#    'fun',
#    'friends',
#    'create',
#    'take',
#    'catch',
#    'flying',
#    'case',
#    'inserted',
#    'become',
#    'expression',
#    'app',
#    'inaccessibleyour',
#    'get',
#    'started',
#    'creativity',
#    'app',
#    'important',
#    'preschool',
#    'environment',
#    'learning',
#    'camera',
#    'takes',
#    'based',
#    'game',
#    'reinforces',
#    'like',
#    'age',
#    'stimulate',
#    'creativity',
#    'clement',
#    'camera',
#    'learning',
#    'includes',
#    'ipod',
#    '5th',
#    'leapfrog',
#    'toys',
#    'touch',
#    'children',
#    'way',
#    'creativity',
#    'camera',
#    'app',
#    'protective',
#    'iphone',
#    'ipod',
#    'touch',
#    'case',
#    'work',
#    'together',
#    'creativity',
#    'camera',
#    'app',
#    'protective',
#    'green',
#    'case',
#    'years',
#    'teaches',
#    'based',
#    'activities'], ['creativity',
#    'touch',
#    'learning',
#    'fun',
#    'case',
#    'protects',
#    'enjoys',
#    'play',
#    'included',
#    'place',
#    'photos',
#    'game',
#    'toy',
#    'turns',
#    'camera',
#    'love',
#    'work',
#    'stretch',
#    'designed',
#    'camera',
#    'power',
#    'focused',
#    'different',
#    'game',
#    'touch',
#    'years',
#    'take',
#    'silly',
#    'little',
#    'six',
#    'album',
#    'frames',
#    'filter',
#    'create',
#    'kind',
#    'silly',
#    'take',
#    'funny',
#    'facial',
#    'flying',
#    'shutterbug',
#    'critters',
#    'protective',
#    'case',
#    'ultimate',
#    'kid',
#    'fun',
#    'apple',
#    'inserted',
#    'personal',
#    'apps',
#    'expression',
#    'menu',
#    'download',
#    'case',
#    'designed',
#    'play',
#    'environment',
#    'ages',
#    'developmentally',
#    'ipod',
#    'creative',
#    'play',
#    'explore',
#    'expression',
#    'innovative',
#    'self',
#    'expression',
#    'beyond',
#    'picture',
#    'box',
#    'app',
#    '4th',
#    'sold',
#    'shapes',
#    'creativity',
#    'camera',
#    'iphone',
#    'ipod',
#    'touch',
#    'leapfrog',
#    'creativity',
#    'create',
#    'learn',
#    'learning',
#    'case',
#    'work',
#    'iphone',
#    'camera',
#    'app',
#    'years',
#    'teaches',
#    'creativity',
#    'curriculum',
#    'experience',
#    'photographer']]}

# %%
stability=0
# count_all=0
for ui in dict_features.keys():
  features=dict_features[ui]
  stabs=0
  count=0
  if(len(features)>1):
    # count_all+=1
    for i in range(len(features)):
      for j in range(len(features)):
        # print(features[i])
        # print(features[j])
        if len(features[i])>0 and len(features[j])>0:
          if i != j:
            intersection = list(set(features[i]) & set(features[j]))
            union = list(set(features[i]) | set(features[j]))
            # print(features[i],features[j])
            # print(intersection)
            # print(union)
            count+=1
            stabs+=(len(intersection)/len(union))
    # print(stabs)
    # print(len(features)*(len(features)-1))
    # print((stabs/(len(features)*(len(features)-1))))
    stability+=(stabs/(9.0*10.0))

stability=stability/len(dict_features)
print(stability)
# Out:
# 0.17575317138745952
